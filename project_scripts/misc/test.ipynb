# %%
import math
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import jax
import jax.numpy as jnp
import jax.scipy.stats as stats
from jax import jacfwd, jacrev
from jax import vmap, grad, jit, random
from jax.tree_util import tree_map, tree_flatten, tree_unflatten, tree_leaves

from flax import nnx
import optax
import pcax

from tqdm.notebook import tqdm
from tqdm.notebook import trange

import torch
from torch.utils.data import DataLoader, TensorDataset

# %%
def jac(model, x):
    f = lambda x: model(x)
    return jax.jacrev(f)(x)
jac = vmap(jac, (None, 0))

# %%
class mlp(nnx.Module):
    def __init__(self, p, rngs: nnx.Rngs):
        self.linear1 = nnx.Linear(p, p, rngs=rngs)
        self.linear2 = nnx.Linear(p, p, rngs=rngs)
    def __call__(self, x):
        x = self.linear1(x)
        x = nnx.tanh(x)
        x = self.linear2(x)
        return x
        
def train_step(model, optimizer, x, y):
    def loss_fn(model):
        y_pred = model(x)
        return jnp.mean((y_pred - y)**2)

    loss, grads = nnx.value_and_grad(loss_fn)(model)
    optimizer.update(grads)
    return loss

# %%
# class mlp(nnx.Module):
#     def __init__(self, p, rngs: nnx.Rngs):
#         self.lin1 = nnx.Linear(p, p//2, rngs=rngs)
#         self.lin2 = nnx.Linear(p//2, p//2, rngs=rngs)
#         self.lin3 = nnx.Linear(p//2, p, rngs=rngs)
#     def __call__(self, x):
#         x = self.lin1(x)
#         x = nnx.relu(x)
#         x = self.lin2(x)
#         x = nnx.relu(x)
#         x = self.lin3(x)
#         return x

# %%
rng = random.PRNGKey(0)
n, p = 5000, 50

theta = np.diag(np.zeros(p))
theta[1,2] = 2
theta[2,1] = 2
theta = theta/jnp.sum(theta)
x = np.array(random.normal(rng, (n, p)))

for i in range(1, n):
    x[i] = theta @ x[i-1] + x[i]
    
y = x[1:]
x = x[:-1]

# %%
plt.imshow(theta)

# %%
model1 = mlp(p = p, rngs = nnx.Rngs(0))
optim = nnx.Optimizer(model1, optax.adam(1e-2))
trace = []
for _ in trange(1000):
    loss = train_step(model1, optim, x, y)
    trace.append(loss)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
jfull1 = jac(model1, x)
plt.plot(jfull1[:,1,2])

# %%
jfull1 = jac(model1, x)
jhat1 = jnp.median(jnp.abs(jfull1), axis = 0)
plt.imshow(jhat1)

# %%
rng = random.PRNGKey(10)
r = np.array(random.normal(rng, (n, p)))
ry = r[1:]
rx = r[:-1]

# %%
model2 = mlp(p = p, rngs = nnx.Rngs(0))
optim = nnx.Optimizer(model2, optax.adam(1e-2))
trace = []
for _ in trange(1000):
    loss = train_step(model2, optim, rx, ry)
    trace.append(loss)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
jfull2 = jac(model2, x)
jhat2 = jnp.median(np.abs(jfull2), axis = 0)
plt.imshow(jhat2)

# %%
jhat2 += jnp.median(jhat2)

# %%
alpha = 0.05
t = jnp.linspace(0, 2, p**2)
fdp = []
for i in trange(len(t)):
    fdp = np.sum(jhat2 >= t[i])/np.sum(jhat1 >= t[i])
    if fdp <= alpha:
        break
tq = t[i]
tq
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# Array(0.15846339, dtype=float32)

# %%
# tq = t[np.argmax(np.array(fdp) <= alpha)]

# %%
fig, ax = plt.subplots(1, 2, constrained_layout = True, figsize = (10, 5))
ax[0].imshow(theta)
ax[0].set_title('Actual')
ax[1].imshow(jhat1 >= tq)
ax[1].set_title('Estimate')
plt.show()

# %%
np.mean(jhat1 >= tq)
# Out:
# Array(0.0008, dtype=float32)

# %%
import os
os.chdir('../models_and_metrics')
from models import *
from metrics import * 
from utility import *
os.chdir('../gpsims')

# %%
dtrain = np.load('../data/temp_train_small.npy', mmap_mode='r+')
nlat, nlon = dtrain.shape[1:]
dtrain = np.mean(dtrain.reshape(-1, 4, nlat, nlon), axis = 1)

# def clim_smooth(data, kernel):
#     return jax.scipy.signal.convolve2d(data, kernel, mode='same')
# clim_smooth = jit(vmap(clim_smooth, (0, None)))

# kernel = jnp.array([[1, 1, 1], [1, 5, 1], [1, 1, 1]])
# kernel = kernel / jnp.sum(kernel)
# dtrain = np.array(clim_smooth(dtrain, kernel))

# %%
dtrain = jax.image.resize(dtrain, (dtrain.shape[0], 12, 24), method = 'bicubic')
dtrain = jnp.mean(dtrain[:121*30].reshape(-1, 30, 12, 24), axis = 1)

lag, lead = 12, 1
xtrain, ytrain = split_data(dtrain, lag, lead)
xtrain = np.moveaxis(xtrain, 1, 3)
ytrain = np.moveaxis(ytrain, 1, 3)
train_data = TensorDataset(torch.Tensor(xtrain), torch.Tensor(ytrain))
train_loader = DataLoader(train_data, batch_size = 64, shuffle = True)

# %%
epochs = 500
width = 50
rng = random.PRNGKey(0)
model_rng = nnx.Rngs(1)

model = DeepANO(lag, width, lead, rngs=model_rng)
optim = nnx.Optimizer(model, optax.adam(1e-3))
trace = []
for _ in trange(epochs):
    for xt, yt in train_loader:
        xt = torch2jax(xt)
        yt = torch2jax(yt)
        loss = train_step(model, optim, xt, yt)
        trace.append(loss)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
plt.imshow(model(xtrain[0:1]).squeeze())

# %%
def spatial_jac(model, x):
    def f(x):
        x = x.reshape(1, 12, 24, 12)
        yhat = model(x)
        return yhat.reshape(-1)
    return jax.jacrev(f)(x)
spatial_jac = vmap(spatial_jac, (None, 0))

# %%
jfull = spatial_jac(model, xtrain.reshape(109, -1))
jhat1 = jnp.mean(jfull, axis = 0).reshape(12*24, 12*24, 12)
jmax1 = jnp.max(jnp.abs(jhat1), axis = 2)
jmax1.shape
# Out:
# (288, 288)

# %%
plt.imshow(jnp.log(jmax1[120]).reshape(12, 24))
plt.colorbar()
plt.show()

# %%
dtest = jax.random.normal(rng, dtrain.shape)
lag, lead = 12, 1
xtest, ytest = split_data(dtest, lag, lead)
xtest = np.moveaxis(xtest, 1, 3)
ytest = np.moveaxis(ytest, 1, 3)
test_data = TensorDataset(torch.Tensor(xtest), torch.Tensor(ytest))
test_loader = DataLoader(test_data, batch_size = 64, shuffle = True)

# %%
epochs = 500
width = 50
rng = random.PRNGKey(0)
model_rng = nnx.Rngs(1)

model2 = DeepANO(lag, width, lead, rngs=model_rng)
optim = nnx.Optimizer(model2, optax.adam(1e-3))
trace = []
for _ in trange(epochs):
    for xt, yt in test_loader:
        xt = torch2jax(xt)
        yt = torch2jax(yt)
        loss = train_step(model2, optim, xt, yt)
        trace.append(loss)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
jax.random.normal(rng, dtrain.shape).shape
# Out:
# (121, 12, 24)

# %%
jbase = spatial_jac(model2, xtest.reshape(109, -1))
jhat2 = jnp.mean(jbase, axis = 0).reshape(12*24, 12*24, 12)
jmax2 = jnp.max(jnp.abs(jhat2), axis = 2)
jmax2.shape
# Out:
# (288, 288)

# %%
alpha = 0.05
t = jnp.linspace(0, 2, 12*24)
fdp = []
for i in trange(len(t)):
    fdp = np.sum(jmax2 >= t[i])/np.sum(jmax1 >= t[i])
    if fdp <= alpha:
        break
tq = t[i]
tq
# Out:
#   0%|          | 0/288 [00:00<?, ?it/s]
# Array(0.1533101, dtype=float32)

# %%
fig, ax = plt.subplots(1, 2, constrained_layout = True, figsize = (10, 5))
ax[1].imshow(jmax1 >= tq)
ax[1].set_title('Estimate')
plt.show()

# %%
class DeepANO(nnx.Module):
    def __init__(self, rngs):
        self.encode_layer = nnx.Conv(12, 32, (3, 5), padding = 'SAME', rngs=rngs)
        self.ano1 = nnx.Conv(32, 32, (3, 5), padding = 'SAME', rngs=rngs)
        self.ano2 = nnx.Conv(32, 32, (3, 5), padding = 'SAME', rngs=rngs)
        self.ano3 = nnx.Conv(32, 32, (3, 5), padding = 'SAME',  rngs=rngs)
        self.ano4 = nnx.Conv(32, 32, (3, 5), padding = 'SAME', rngs=rngs)
        self.ano5 = nnx.Conv(32, 32, (3, 5), padding = 'SAME',  rngs=rngs)
        self.decode_layer = nnx.Conv(32, 1, (3, 5), padding = 'SAME',  rngs=rngs)

    def __call__(self, x):
        x0 = self.encode_layer(x)
        x1 = self.ano1(x0)
        x2 = self.ano2(x1)
        x3 = x2 + self.ano3(x2)
        x4 = x1 + self.ano4(x3)
        x5 = x0 + self.ano5(x4)
        x6 = self.decode_layer(x5)
        return x6

# %%
epochs = 500
width = 50
rng = random.PRNGKey(0)
model_rng = nnx.Rngs(1)

model = DeepANO(rngs=model_rng)
optim = nnx.Optimizer(model, optax.adam(1e-3))
trace = []
for _ in trange(epochs):
    for xt, yt in train_loader:
        xt = torch2jax(xt)
        yt = torch2jax(yt)
        loss = train_step(model, optim, xt, yt)
        trace.append(loss)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
xtrain.shape
# Out:
# (120, 1, 12, 24)

# %%
jfull = spatial_jac(model, xtrain.reshape(120, -1))
jhat1 = jnp.mean(jfull, axis = 0).reshape(12*24, 12*24, 12)
jmax1 = jnp.max(jnp.abs(jhat1), axis = 2)
jmax1.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 jfull = spatial_jac(model, xtrain.reshape(120, -1))
#       2 jhat1 = jnp.mean(jfull, axis = 0).reshape(12*24, 12*24, 12)
#       3 jmax1 = jnp.max(jnp.abs(jhat1), axis = 2)
#
#     [... skipping hidden 3 frame]
#
# Cell In[69], line 6, in spatial_jac(model, x)
#       4     yhat = model(x)
#       5     return yhat.reshape(-1)
# ----> 6 return jax.jacrev(f)(x)
#
#     [... skipping hidden 7 frame]
#
# Cell In[69], line 4, in spatial_jac.<locals>.f(x)
#       2 def f(x):
#       3     x = x.reshape(1, 12, 24, 1)
# ----> 4     yhat = model(x)
#       5     return yhat.reshape(-1)
#
# Cell In[62], line 12, in DeepANO.__call__(self, x)
#      11 def __call__(self, x):
# ---> 12     x0 = self.encode_layer(x)
#      13     x1 = self.ano1(x0)
#      14     x2 = self.ano2(x1)
#
# File ~/miniconda3/lib/python3.10/site-packages/flax/nnx/nnx/nn/linear.py:777, in Conv.__call__(self, inputs)
#     771 bias = self.bias.value
#     773 inputs, kernel, bias = dtypes.promote_dtype(
#     774   (inputs, kernel, bias), dtype=self.dtype
#     775 )
# --> 777 y = self.conv_general_dilated(
#     778   inputs,
#     779   kernel,
#     780   strides,
#     781   padding_lax,
#     782   lhs_dilation=input_dilation,
#     783   rhs_dilation=kernel_dilation,
#     784   dimension_numbers=dimension_numbers,
#     785   feature_group_count=self.feature_group_count,
#     786   precision=self.precision,
#     787 )
#     789 if self.use_bias:
#     790   bias = bias.reshape((1,) * (y.ndim - bias.ndim) + bias.shape)  # type: ignore
#
#     [... skipping hidden 32 frame]
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/convolution.py:374, in _conv_general_dilated_shape_rule(lhs, rhs, window_strides, padding, lhs_dilation, rhs_dilation, dimension_numbers, feature_group_count, batch_group_count, **unused_kwargs)
#     370 if not core.definitely_equal(quot, rhs.shape[dimension_numbers.rhs_spec[1]]):
#     371   msg = ("conv_general_dilated lhs feature dimension size divided by "
#     372          "feature_group_count must equal the rhs input feature dimension "
#     373          "size, but {} // {} != {}.")
# --> 374   raise ValueError(msg.format(lhs_feature_count, feature_group_count,
#     375                               rhs.shape[dimension_numbers.rhs_spec[1]]))
#     376 if rhs.shape[dimension_numbers.rhs_spec[0]] % feature_group_count:
#     377   msg = ("conv_general_dilated rhs output feature dimension size must be a "
#     378          "multiple of feature_group_count, but {} is not a multiple of {}.")
#
# ValueError: conv_general_dilated lhs feature dimension size divided by feature_group_count must equal the rhs input feature dimension size, but 1 // 1 != 12.

# %%
plt.imshow(jmax1[20].reshape(12, 24))
plt.colorbar()
plt.show()

# %%
dtest = jax.random.normal(rng, dtrain.shape)
lag, lead = 12, 1
xtest, ytest = split_data(dtest, lag, lead)
xtest = np.moveaxis(xtest, 1, 3)
ytest = np.moveaxis(ytest, 1, 3)
test_data = TensorDataset(torch.Tensor(xtest), torch.Tensor(ytest))
test_loader = DataLoader(test_data, batch_size = 64, shuffle = True)

# %%
epochs = 500
width = 50
rng = random.PRNGKey(0)
model_rng = nnx.Rngs(1)

model2 = DeepANO(rngs=model_rng)
optim = nnx.Optimizer(model2, optax.adam(1e-3))
trace = []
for _ in trange(epochs):
    for xt, yt in train_loader:
        xt = torch2jax(xt)
        yt = torch2jax(yt)
        loss = train_step(model2, optim, xt, yt)
        trace.append(loss)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
jbase = spatial_jac(model2, xtest.reshape(109, -1))
jhat2 = jnp.mean(jbase, axis = 0).reshape(12*24, 12*24, 12)
jmax2 = jnp.max(jnp.abs(jhat2), axis = 2)
jmax2.shape
# Out:
# (288, 288)

# %%
alpha = 0.05
t = jnp.linspace(0, 2, 12*24)
fdp = []
for i in trange(len(t)):
    fdp = np.sum(jmax2 >= t[i])/np.sum(jmax1 >= t[i])
    if fdp <= alpha:
        break
tq = t[i]
tq
# Out:
#   0%|          | 0/288 [00:00<?, ?it/s]
# Array(2., dtype=float32)

# %%
fig, ax = plt.subplots(1, 2, constrained_layout = True, figsize = (10, 5))
ax[1].imshow(jmax1 >= tq)
ax[1].set_title('Estimate')
plt.show()

# %%
class DeepANO(nnx.Module):
    def __init__(self, rngs):
        self.encode_layer = nnx.Linear(288, 32, rngs=rngs)
        self.ano1 = nnx.Linear(32, 32, rngs=rngs)
        self.ano2 = nnx.Linear(32, 32, rngs=rngs)
        self.ano3 = nnx.Linear(32, 32, rngs=rngs)
        self.decode_layer = nnx.Linear(32, 288, rngs=rngs)

    def __call__(self, x):
        x0 = self.encode_layer(x)
        x1 = self.ano1(x0)
        x2 = x1 + self.ano2(x1)
        x3 = x0 + self.ano3(x2)
        x4 = self.decode_layer(x3)
        return x4

# %%
def spatial_jac(model, x):
    def f(x):
        yhat = model(x)
        return yhat.squeeze()
    return jax.jacrev(f)(x)
spatial_jac = vmap(spatial_jac, (None, 0))

# %%
epochs = 500
rng = random.PRNGKey(0)
model_rng = nnx.Rngs(1)

model = DeepANO(rngs=model_rng)
optim = nnx.Optimizer(model, optax.adam(1e-3))
trace = []
for _ in trange(epochs):
    for xt, yt in train_loader:
        xt = torch2jax(xt).reshape(xt.shape[0], -1)
        yt = torch2jax(yt).reshape(yt.shape[0], -1)
        loss = train_step(model, optim, xt, yt)
        trace.append(loss)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
jfull = spatial_jac(model, xtrain.reshape(120, -1))
jhat = jnp.mean(jfull, axis = 0)

# %%
plt.imshow(jhat[:,64].reshape(12, 24))
plt.colorbar()
plt.show()

# %%
class DeepANO(nnx.Module):
    def __init__(self, rngs):
        self.encode_layer = nnx.MultiHeadAttention(num_heads=8, in_features=1, qkv_features=16,
                               decode=False, rngs=nnx.Rngs(0))

    def __call__(self, x):
        x = self.encode_layer(x)
        return x

# %%
epochs = 50
rng = random.PRNGKey(0)
model_rng = nnx.Rngs(1)

model = DeepANO(rngs=model_rng)
optim = nnx.Optimizer(model, optax.adam(1e-3))
trace = []
for _ in trange(epochs):
    for xt, yt in train_loader:
        xt = torch2jax(xt).reshape(xt.shape[0], -1, 1)
        yt = torch2jax(yt).reshape(yt.shape[0], -1, 1)
        loss = train_step(model, optim, xt, yt)
        trace.append(loss)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
def spatial_jac(model, x):
    def f(x):
        x = x.reshape(1, 12*24, 1)
        yhat = model(x)
        return yhat.reshape(-1)
    return jax.jacrev(f)(x)
spatial_jac = vmap(spatial_jac, (None, 0))

# %%
jfull = spatial_jac(model, xtrain.reshape(120, -1))
jhat = jnp.mean(jfull, axis = 0)
