# %%
import math
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import jax
import jax.numpy as jnp
import jax.scipy.stats as stats
from jax import jacfwd, jacrev
from jax import vmap, grad, jit, random
from jax.tree_util import tree_map, tree_flatten, tree_unflatten, tree_leaves

from flax import nnx
import optax
import pcax

from tqdm.notebook import tqdm
from tqdm.notebook import trange

import torch
import torch_harmonics as th
from torch_harmonics.random_fields import GaussianRandomFieldS2

from torch.utils.data import DataLoader, TensorDataset

import os
os.chdir('../methods')
import lsci, supr, conf, uqno, prob_don, quant_don, gaus
os.chdir('../gpsims')

os.chdir('../models_and_metrics')
from models import *
from metrics import * 
from utility import *
os.chdir('../gpsims')

# %%
n = 500
s = jnp.linspace(-2*math.pi, 2*math.pi, n+1)
amp = jnp.sin(s)
sd = 1.25 + jnp.sin(s)

gp2d = GaussianRandomFieldS2(nlat = 30)
xtrain = gp2d(n+1).numpy()
xtrain = 10 + amp[:,None,None] + sd[:,None,None] * jnp.array(xtrain)
xtrain, ytrain = split_data(xtrain, 1, 1)
xtrain = xtrain[:,0,:,:,None]
ytrain = ytrain[:,0,:,:,None]

gp2d = GaussianRandomFieldS2(nlat = 30)
xval = gp2d(n+1).numpy()
xval = 10 + amp[:,None,None] + sd[:,None,None] * jnp.array(xval)
xval, yval = split_data(xval, 1, 1)
xval = xval[:,0,:,:,None]
yval = yval[:,0,:,:,None]

gp2d = GaussianRandomFieldS2(nlat = 30)
xtest = gp2d(n+1).numpy()
xtest = 10 + amp[:,None,None] + sd[:,None,None] * jnp.array(xtest)
xtest, ytest = split_data(xtest, 1, 1)
xtest = xtest[:,0,:,:,None]
ytest = ytest[:,0,:,:,None]

# %%
train_data = TensorDataset(torch.Tensor(xtrain), torch.Tensor(ytrain))
train_loader = DataLoader(train_data, batch_size = 30, shuffle = True)

# %%
epochs = 50
trace = []
lag, lead = 1, 1

width = 50
drop_prob = 0.1

rng = random.PRNGKey(0)
model_rng = nnx.Rngs(0)
base_model = DeepANO(lag, width, lead, rngs=model_rng)
drop_model = DropANO(lag, width, lead, drop_prob, rngs=model_rng)
prob_model = ProbANO(lag, width, lead, rngs=model_rng)
quant_model = DeepANO(lag, width, lead, rngs=model_rng)

base_optim = nnx.Optimizer(base_model, optax.adam(1e-3))
drop_optim = nnx.Optimizer(drop_model, optax.adam(1e-3))
prob_optim = nnx.Optimizer(prob_model, optax.adam(1e-3))
quant_optim = nnx.Optimizer(quant_model, optax.adam(1e-3))

for _ in trange(epochs):
    for xt, yt in train_loader:
        xt = torch2jax(xt)
        yt = torch2jax(yt)
        
        base_loss = train_step(base_model, base_optim, xt, yt)
        drop_loss = train_step(drop_model, drop_optim, xt, yt)
        prob_loss = prob_step(prob_model, prob_optim, xt, yt)
        quant_loss = quant_step(quant_model, quant_optim, xt, yt)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
yval_hat = base_model(xval)
ytest_hat = base_model(xtest)

yval_quant = quant_model(xval)
ytest_quant = quant_model(xtest)

yval_mu, yval_sd = prob_model(xval)
ytest_mu, ytest_sd = prob_model(xtest)

# %%
yval = yval.reshape(n, -1)
ytest = ytest.reshape(n, -1)

yval_hat = yval_hat.reshape(n, -1)
ytest_hat = ytest_hat.reshape(n, -1)
yval_quant = yval_quant.reshape(n, -1)
ytest_quant = ytest_quant.reshape(n, -1)
yval_mu = yval_mu.reshape(n, -1)
yval_sd = yval_sd.reshape(n, -1)
ytest_mu = ytest_mu.reshape(n, -1)
ytest_sd = ytest_sd.reshape(n, -1)

# %%
yval_hat.shape
# Out:
# (500, 1800)

# %%
nproj = npc = 200
gamma1 = 0.1
gamma2 = 0.05
alpha = 0.1
nval = xval.shape[0]

drop_risk, drop_width = [], []
orcl_risk, orcl_width = [], []
conf_risk, conf_width = [], []
gaus_risk, gaus_width = [], []
supr_risk, supr_width = [], []
uqn1_risk, uqn1_width = [], []
pdon_risk, pdon_width = [], []
qdon_risk, qdon_width = [], []
lsc1_risk, lsc1_width = [], []
lsc2_risk, lsc2_width = [], []

rval = (yval - yval_hat).reshape(n, -1)
rtest = (ytest - ytest_hat).reshape(n, -1)
rtest2 = (ytest - ytest_mu).reshape(n, -1)

state = lsci.lsci_state(xval.reshape(n, -1), rval, npc)
pca_state = state[-1]

quant_scores = jnp.abs(yval - yval_hat) / yval_quant
lam_uqno = uqno.estimate_lambda(quant_scores, 0.1, 0.01, 1.1)

conf_lower, conf_upper = conf.conf_band(rval, pca_state, alpha)
gaus_lower, gaus_upper = gaus.gaus_band(rval, pca_state, alpha)
supr_lower, supr_upper = supr.supr_band(rval, alpha)
uqn1_lower, uqn1_upper = uqno.uqno_band(ytest_quant, lam_uqno)
pdon_lower, pdon_upper = prob_don.prob_don(prob_model, xval, xtest, yval, alpha)
qdon_lower, qdon_upper = quant_don.quant_don(quant_model, xval, xtest, yval - yval_hat, alpha)

for i in trange(0, ytest.shape[0]):
    
    xtest_i = xtest[i].reshape(1, -1)
    rtest_i = rtest[i].reshape(1, -1)
    
    # LSCI
    lsc1_lower, lsc1_upper = lsci.lsci_band(xtest_i, state, alpha, 2000, gamma1)
    lsc1_risk.append(risk(lsc1_lower, lsc1_upper, rtest_i))
    lsc1_width.append(jnp.median(lsc1_upper - lsc1_lower))
    
    # LSCI
    lsc2_lower, lsc2_upper = lsci.lsci_band(xtest_i, state, alpha, 2000, gamma2)
    lsc2_risk.append(risk(lsc2_lower, lsc2_upper, rtest_i))
    lsc2_width.append(jnp.median(lsc2_upper - lsc2_lower))

    # Oracle
    orcl_lower = -(jnp.abs(rtest[i]) + 1e-4)
    orcl_upper = jnp.abs(rtest[i]) + 1e-4
    orcl_risk.append(risk(orcl_lower, orcl_upper, rtest_i))
    orcl_width.append(jnp.median(orcl_upper - orcl_lower))
    
    # CONF 
    conf_risk.append(risk(conf_lower, conf_upper, rtest_i))
    conf_width.append(jnp.median(conf_upper - conf_lower))
    
    # GAUSS 
    gaus_risk.append(risk(gaus_lower, gaus_upper, rtest_i))
    gaus_width.append(jnp.median(gaus_upper - gaus_lower))
    
    # SUPR
    supr_risk.append(risk(supr_lower, supr_upper, rtest_i))
    supr_width.append(jnp.median(supr_upper - supr_lower))
    
    # UQNO
    uqn1_risk.append(risk(uqn1_lower[i], uqn1_upper[i], rtest_i))
    uqn1_width.append(jnp.median(uqn1_upper[i] - uqn1_lower[i]))
    
    # PDON
    pdon_risk.append(risk(pdon_lower[i], pdon_upper[i], rtest_i))
    pdon_width.append(jnp.median(pdon_upper[i] - pdon_lower[i]))
    
    # PDON
    qdon_risk.append(risk(qdon_lower[i], qdon_upper[i], rtest_i))
    qdon_width.append(jnp.median(qdon_upper[i] - qdon_lower[i]))
    
    # DROPOUT
    drop_model.train()
    drop_set = jnp.stack([drop_model(xtest[i:(i+1)]).squeeze() for _ in range(500)])
    drop_set = drop_set.reshape(500, -1)
    drop_lower = jnp.quantile(drop_set, alpha/2, axis = 0)
    drop_upper = jnp.quantile(drop_set, 1 - alpha/2, axis = 0)
    drop_model.eval()
    
    drop_risk.append(risk(drop_lower, drop_upper, rtest_i))
    drop_width.append(jnp.median(drop_upper - drop_lower))


orcl_risk, orcl_width = np.array(orcl_risk), np.array(orcl_width)
drop_risk, drop_width = np.array(drop_risk), np.array(drop_width)
conf_risk, conf_width = np.array(conf_risk), np.array(conf_width)
gaus_risk, gaus_width = np.array(gaus_risk), np.array(gaus_width)
supr_risk, supr_width = np.array(supr_risk), np.array(supr_width)
uqn1_risk, uqn1_width = np.array(uqn1_risk), np.array(uqn1_width)
lsc1_risk, lsc1_width = np.array(lsc1_risk), np.array(lsc1_width)
lsc2_risk, lsc2_width = np.array(lsc2_risk), np.array(lsc2_width)
pdon_risk, pdon_width = np.array(pdon_risk), np.array(pdon_width)
qdon_risk, qdon_width = np.array(qdon_risk), np.array(qdon_width)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 82
#      80 # DROPOUT
#      81 drop_model.train()
# ---> 82 drop_set = jnp.stack([drop_model(xtest[i:(i+1)]).squeeze() for _ in range(500)])
#      83 drop_set = drop_set.reshape(500, -1)
#      84 drop_lower = jnp.quantile(drop_set, alpha/2, axis = 0)
#
# Cell In[8], line 82, in <listcomp>(.0)
#      80 # DROPOUT
#      81 drop_model.train()
# ---> 82 drop_set = jnp.stack([drop_model(xtest[i:(i+1)]).squeeze() for _ in range(500)])
#      83 drop_set = drop_set.reshape(500, -1)
#      84 drop_lower = jnp.quantile(drop_set, alpha/2, axis = 0)
#
# File ~/research/LSCI/models_and_metrics/models.py:76, in DropANO.__call__(self, x)
#      74 x = self.ano1(x)
#      75 x = self.dropout(x)
# ---> 76 x = self.ano2(x)
#      77 x = self.dropout(x)
#      78 x = self.ano3(x)
#
# File ~/research/LSCI/models_and_metrics/models.py:18, in ANO_layer.__call__(self, x)
#      15 h = self.linear(x)
#      17 # spatial mix
# ---> 18 g = jnp.mean(x, axis = (1, 2))[:,None,None,:]
#      20 # sum
#      21 x = h + g
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/array.py:337, in ArrayImpl.__getitem__(self, idx)
#     334     else:
#     335       return out
# --> 337 return lax_numpy._rewriting_take(self, idx)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:5126, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    5123       return lax.dynamic_index_in_dim(arr, idx, keepdims=False)
#    5125 treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# -> 5126 return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    5127                unique_indices, mode, fill_value)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:5167, in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#    5164   y = lax.rev(y, indexer.reversed_y_dims)
#    5166 # This adds np.newaxis/None dimensions.
# -> 5167 return expand_dims(y, indexer.newaxis_dims)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:1130, in expand_dims(a, axis)
#    1128 util.check_arraylike("expand_dims", a)
#    1129 axis = _ensure_index_tuple(axis)
# -> 1130 return lax.expand_dims(a, axis)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:1388, in expand_dims(array, dimensions)
#    1386   result_shape.insert(i, 1)
#    1387 broadcast_dims = [i for i in range(ndim_out) if i not in dims_set]
# -> 1388 return broadcast_in_dim(array, result_shape, broadcast_dims)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:831, in broadcast_in_dim(operand, shape, broadcast_dimensions)
#     829 else:
#     830   dyn_shape, static_shape = [], shape  # type: ignore
# --> 831 return broadcast_in_dim_p.bind(
#     832     operand, *dyn_shape, shape=tuple(static_shape),
#     833     broadcast_dimensions=tuple(broadcast_dimensions))
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:387, in Primitive.bind(self, *args, **params)
#     384 def bind(self, *args, **params):
#     385   assert (not config.enable_checks.value or
#     386           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 387   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:390, in Primitive.bind_with_trace(self, trace, args, params)
#     389 def bind_with_trace(self, trace, args, params):
# --> 390   with pop_level(trace.level):
#     391     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     392   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.10/contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:1216, in pop_level(level)
#    1213 @contextmanager
#    1214 def pop_level(level: int):
#    1215   if level == 0:
# -> 1216     return (yield)
#    1217   prev, thread_local_state.trace_state.trace_stack.stack = \
#    1218       thread_local_state.trace_state.trace_stack.stack, \
#    1219       thread_local_state.trace_state.trace_stack.stack[:level]
#    1220   try:
#
# KeyboardInterrupt:

# %%
sigma = 0.25 * (1.15 + sd)
noise_sd = sigma[1:]
gamma = 0.99

risk_control = np.mean(orcl_risk >= gamma), \
               np.mean(drop_risk >= gamma), \
               np.mean(conf_risk >= gamma), \
               np.mean(gaus_risk >= gamma), \
               np.mean(supr_risk >= gamma), \
               np.mean(uqn1_risk >= gamma), \
               np.mean(pdon_risk >= gamma), \
               np.mean(qdon_risk >= gamma), \
               np.mean(lsc1_risk >= gamma), \
               np.mean(lsc2_risk >= gamma)

width = np.mean(orcl_width), \
        np.mean(drop_width), \
        np.mean(conf_width), \
        np.mean(gaus_width), \
        np.mean(supr_width), \
        np.mean(uqn1_width), \
        np.mean(pdon_width), \
        np.mean(qdon_width), \
        np.mean(lsc1_width), \
        np.mean(lsc2_width)

risk_cor = -0, \
           np.corrcoef([noise_sd, drop_risk])[0,1], \
           np.corrcoef([noise_sd, conf_risk])[0,1], \
           np.corrcoef([noise_sd, gaus_risk])[0,1], \
           np.corrcoef([noise_sd, supr_risk])[0,1], \
           np.corrcoef([noise_sd, uqn1_risk])[0,1], \
           np.corrcoef([noise_sd, pdon_risk])[0,1], \
           np.corrcoef([noise_sd, qdon_risk])[0,1], \
           np.corrcoef([noise_sd, lsc1_risk])[0,1], \
           np.corrcoef([noise_sd, lsc2_risk])[0,1]

width_cor = 1, \
            np.corrcoef([noise_sd, drop_width])[0,1], \
            0, \
            0, \
            0, \
            np.corrcoef([noise_sd, uqn1_width])[0,1], \
            np.corrcoef([noise_sd, pdon_width])[0,1], \
            np.corrcoef([noise_sd, qdon_width])[0,1], \
            np.corrcoef([noise_sd, lsc1_width])[0,1], \
            np.corrcoef([noise_sd, lsc2_width])[0,1]

metrics = np.array([risk_control, risk_cor, width, width_cor]).T

# %%
orcl_width

# %%
for i in range(metrics.shape[0]):
    for j in range(metrics.shape[1]):
        val = f'{np.round(np.nan_to_num(metrics[i,j]), 3):.3f}'
        if j < 3:
            val += ' & '
            print(val, end = '')
        else:
            val += ' \\\\'
            print(val)

# %%
methods = ['Oracle', 'MC-Drop', 'Conf1', 'Conf2', 
           'Supr', 'CQR-NO', 'Prob-NO', 'Quant-NO', 
           'LSCI1', 'LSCI2']

for i in range(metrics.shape[0]):
    print(f'{methods[i]} & ', end = '')
    for j in range(metrics.shape[1]):
        val = f'{np.round(np.nan_to_num(metrics[i,j]), 3):.3f}'
        if j < 3:
            val += ' & '
            print(val, end = '')
        else:
            val += ' \\\\'
            print(val)
# Out:
# Oracle & 1.000 & 0.000 & 0.170 & 1.000 \\
# MC-Drop & 0.000 & 0.000 & 0.392 & 0.997 \\
# Conf1 & 0.810 & -0.582 & 1.070 & 0.000 \\
# Conf2 & 0.778 & -0.613 & 1.028 & 0.000 \\
# Supr & 0.930 & -0.511 & 1.210 & 0.000 \\
# CQR-NO & 0.778 & -0.628 & 0.916 & 0.999 \\
# Prob-NO & 0.447 & -0.867 & 0.553 & -0.999 \\
# Quant-NO & 0.854 & 0.482 & 2.219 & 0.999 \\
# LSCI1 & 0.946 & 0.006 & 0.837 & 0.998 \\
# LSCI2 & 0.906 & 0.010 & 0.823 & 0.998 \\

# %%
# DCT based fpca?

# %%
def dct_basis(N, K):
    basis = np.zeros((N, K))
    n_seq = np.arange(N)
    
    basis[:,0] = np.sqrt(1 / N)
    for k in range(1, K):
        basis[:,k] = np.cos((math.pi / N) * (n_seq + 0.5) * k)
        basis[:,k] = basis[:,k] * np.sqrt(2 / N)  
    return basis.T

def dct_project(f, nvr = None, nvc = None):
    n1, p1r, p1c = f.shape
    dct1r = dct_basis(p1r, nvr)
    dct1c = dct_basis(p1c, nvc).T
    xi = (dct1r @ f @ dct1c).reshape(-1, nvr * nvc)
    return xi, [dct1r, dct1c]

def dct_invert(xi, basis, nvr = None, nvc = None):
    dct1r, dct1c = basis
    p1r, p1c = dct1r.shape[0], dct1c.shape[1]
    return dct1r.T @ xi.reshape(-1, p1r, p1c) @ dct1c.T

def low_pass(x, d1, d2):
    xi, basis = dct_project(x, d1, d2)
    return dct_invert(xi, basis)

# %%
n = 501
s = jnp.linspace(-2*math.pi, 2*math.pi, n+1)
amp = jnp.sin(s)
sd = 1.25 + jnp.sin(s)

gp2d = GaussianRandomFieldS2(nlat = 30)
xtrain = gp2d(n+1).numpy()
xtrain = 10 + amp[:,None,None] + sd[:,None,None] * jnp.array(xtrain)
xtrain, ytrain = split_data(xtrain, 1, 1)
xtrain = xtrain[:,0,:,:,None]
ytrain = ytrain[:,0,:,:,None]

gp2d = GaussianRandomFieldS2(nlat = 30)
xval = gp2d(n+1).numpy()
xval = 10 + amp[:,None,None] + sd[:,None,None] * jnp.array(xval)
xval, yval = split_data(xval, 1, 1)
xval = xval[:,0,:,:,None]
yval = yval[:,0,:,:,None]

gp2d = GaussianRandomFieldS2(nlat = 30)
xtest = gp2d(n+1).numpy()
xtest = 10 + amp[:,None,None] + sd[:,None,None] * jnp.array(xtest)
xtest, ytest = split_data(xtest, 1, 1)
xtest = xtest[:,0,:,:,None]
ytest = ytest[:,0,:,:,None]

# %%
yval_hat = base_model(xval)
ytest_hat = base_model(xtest)

yval = yval.reshape(n, -1)
ytest = ytest.reshape(n, -1)
yval_hat = yval_hat.reshape(n, -1)
ytest_hat = ytest_hat.reshape(n, -1)

# %%
nproj = npc = 50
gamma1 = 0.1
gamma2 = 0.01
alpha = 0.1
p1, p2 = 20, 30
rval = (yval - yval_hat).reshape(-1, 30, 60)
rtest = (ytest - ytest_hat).reshape(-1, 30, 60)

rval = low_pass(rval, p1, p2).reshape(n, -1)
rtest = low_pass(rtest, p1, p2).reshape(n, -1)
xval = low_pass(xval.squeeze(), p1, p2).reshape(n, -1)
xtest = low_pass(xtest.squeeze(), p1, p2).reshape(n, -1)

state = lsci.lsci_state(xval, rval, npc)
pca_state = state[-1]

# %%
xtest.shape
# Out:
# (501, 1800)

# %%
lsc1_risk = []
for i in trange(500):
    lsc1_lower, lsc1_upper = lsci.lsci_band(xtest[i].squeeze(), state, alpha, 2000, gamma2)
    lsc1_risk.append(risk(lsc1_lower, lsc1_upper, rtest[i]))
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
np.mean(np.array(lsc1_risk) >= 0.99)
# Out:
# 0.088

# %%
lsc1_risk
# Out:
# [Array(0.9727778, dtype=float32),
#  Array(0.8983334, dtype=float32),
#  Array(0.98444444, dtype=float32),
#  Array(0.98444444, dtype=float32),
#  Array(0.97944444, dtype=float32),
#  Array(0.95944446, dtype=float32),
#  Array(0.9711111, dtype=float32),
#  Array(0.9616667, dtype=float32),
#  Array(0.9255556, dtype=float32),
#  Array(0.95500004, dtype=float32),
#  Array(0.9572222, dtype=float32),
#  Array(0.8927778, dtype=float32),
#  Array(0.9277778, dtype=float32),
#  Array(0.88222224, dtype=float32),
#  Array(0.8616667, dtype=float32),
#  Array(0.9016667, dtype=float32),
#  Array(0.98222226, dtype=float32),
#  Array(0.9027778, dtype=float32),
#  Array(0.9538889, dtype=float32),
#  Array(0.95000005, dtype=float32),
#  Array(0.95055556, dtype=float32),
#  Array(0.93833333, dtype=float32),
#  Array(0.95000005, dtype=float32),
#  Array(0.88222224, dtype=float32),
#  Array(0.87111115, dtype=float32),
#  Array(0.94611114, dtype=float32),
#  Array(0.935, dtype=float32),
#  Array(0.9105556, dtype=float32),
#  Array(0.9827778, dtype=float32),
#  Array(0.92722225, dtype=float32),
#  Array(0.93611115, dtype=float32),
#  Array(0.99722224, dtype=float32),
#  Array(0.87833333, dtype=float32),
#  Array(0.9788889, dtype=float32),
#  Array(0.87222224, dtype=float32),
#  Array(0.98611116, dtype=float32),
#  Array(0.9955556, dtype=float32),
#  Array(0.9672223, dtype=float32),
#  Array(0.9494445, dtype=float32),
#  Array(0.99833333, dtype=float32),
#  Array(0.93, dtype=float32),
#  Array(0.98833334, dtype=float32),
#  Array(0.9155556, dtype=float32),
#  Array(0.9277778, dtype=float32),
#  Array(0.85722226, dtype=float32),
#  Array(0.97333336, dtype=float32),
#  Array(0.9705556, dtype=float32),
#  Array(0.9988889, dtype=float32),
#  Array(0.9494445, dtype=float32),
#  Array(0.8966667, dtype=float32),
#  Array(0.855, dtype=float32),
#  Array(0.9888889, dtype=float32),
#  Array(0.9477778, dtype=float32),
#  Array(0.8266667, dtype=float32),
#  Array(0.9316667, dtype=float32),
#  Array(0.9894445, dtype=float32),
#  Array(0.97833335, dtype=float32),
#  Array(0.9977778, dtype=float32),
#  Array(0.92611116, dtype=float32),
#  Array(0.92722225, dtype=float32),
#  Array(0.97, dtype=float32),
#  Array(0.9788889, dtype=float32),
#  Array(0.98444444, dtype=float32),
#  Array(0.91388893, dtype=float32),
#  Array(0.9538889, dtype=float32),
#  Array(0.93111116, dtype=float32),
#  Array(0.94500005, dtype=float32),
#  Array(0.9355556, dtype=float32),
#  Array(0.98222226, dtype=float32),
#  Array(0.97444445, dtype=float32),
#  Array(0.85722226, dtype=float32),
#  Array(0.93833333, dtype=float32),
#  Array(0.8455556, dtype=float32),
#  Array(0.77944446, dtype=float32),
#  Array(0.97333336, dtype=float32),
#  Array(0.9622222, dtype=float32),
#  Array(0.8372222, dtype=float32),
#  Array(0.97944444, dtype=float32),
#  Array(0.95055556, dtype=float32),
#  Array(0.94, dtype=float32),
#  Array(0.96888894, dtype=float32),
#  Array(0.95611113, dtype=float32),
#  Array(0.9527778, dtype=float32),
#  Array(0.9588889, dtype=float32),
#  Array(0.8677778, dtype=float32),
#  Array(0.99833333, dtype=float32),
#  Array(0.9766667, dtype=float32),
#  Array(0.9705556, dtype=float32),
#  Array(0.98611116, dtype=float32),
#  Array(0.9916667, dtype=float32),
#  Array(0.9427778, dtype=float32),
#  Array(0.95555556, dtype=float32),
#  Array(0.9127778, dtype=float32),
#  Array(0.93222225, dtype=float32),
#  Array(0.9072223, dtype=float32),
#  Array(0.9661111, dtype=float32),
#  Array(0.97722226, dtype=float32),
#  Array(0.96944445, dtype=float32),
#  Array(0.9577778, dtype=float32),
#  Array(0.89111114, dtype=float32),
#  Array(0.9483334, dtype=float32),
#  Array(0.9855556, dtype=float32),
#  Array(0.96944445, dtype=float32),
#  Array(0.9711111, dtype=float32),
#  Array(0.97388893, dtype=float32),
#  Array(0.99, dtype=float32),
#  Array(0.9488889, dtype=float32),
#  Array(0.99222225, dtype=float32),
#  Array(0.89500004, dtype=float32),
#  Array(0.9583334, dtype=float32),
#  Array(0.95611113, dtype=float32),
#  Array(0.96888894, dtype=float32),
#  Array(0.90000004, dtype=float32),
#  Array(0.97722226, dtype=float32),
#  Array(0.96833336, dtype=float32),
#  Array(0.94111115, dtype=float32),
#  Array(0.93722224, dtype=float32),
#  Array(0.8755556, dtype=float32),
#  Array(0.8577778, dtype=float32),
#  Array(0.9327778, dtype=float32),
#  Array(0.98833334, dtype=float32),
#  Array(0.97388893, dtype=float32),
#  Array(0.9811111, dtype=float32),
#  Array(0.92222226, dtype=float32),
#  Array(0.9566667, dtype=float32),
#  Array(0.9927778, dtype=float32),
#  Array(0.9405556, dtype=float32),
#  Array(0.98833334, dtype=float32),
#  Array(0.87111115, dtype=float32),
#  Array(0.9705556, dtype=float32),
#  Array(0.91444445, dtype=float32),
#  Array(0.9816667, dtype=float32),
#  Array(0.94, dtype=float32),
#  Array(0.8605556, dtype=float32),
#  Array(0.91944444, dtype=float32),
#  Array(0.9927778, dtype=float32),
#  Array(0.9077778, dtype=float32),
#  Array(0.95555556, dtype=float32),
#  Array(0.96444446, dtype=float32),
#  Array(0.9827778, dtype=float32),
#  Array(0.99, dtype=float32),
#  Array(0.9866667, dtype=float32),
#  Array(0.97944444, dtype=float32),
#  Array(0.92, dtype=float32),
#  Array(0.9655556, dtype=float32),
#  Array(0.96944445, dtype=float32),
#  Array(0.97333336, dtype=float32),
#  Array(0.9227778, dtype=float32),
#  Array(0.9988889, dtype=float32),
#  Array(0.9755556, dtype=float32),
#  Array(0.95555556, dtype=float32),
#  Array(0.9288889, dtype=float32),
#  Array(0.9116667, dtype=float32),
#  Array(0.95611113, dtype=float32),
#  Array(0.975, dtype=float32),
#  Array(0.97444445, dtype=float32),
#  Array(0.98333335, dtype=float32),
#  Array(0.99833333, dtype=float32),
#  Array(0.9888889, dtype=float32),
#  Array(0.99666667, dtype=float32),
#  Array(1., dtype=float32),
#  Array(0.88500005, dtype=float32),
#  Array(0.88555557, dtype=float32),
#  Array(0.97, dtype=float32),
#  Array(0.9755556, dtype=float32),
#  Array(0.9666667, dtype=float32),
#  Array(0.90833336, dtype=float32),
#  Array(0.9377778, dtype=float32),
#  Array(0.98722225, dtype=float32),
#  Array(0.9805556, dtype=float32),
#  Array(0.8927778, dtype=float32),
#  Array(0.9705556, dtype=float32),
#  Array(0.94166666, dtype=float32),
#  Array(0.9177778, dtype=float32),
#  Array(0.9066667, dtype=float32),
#  Array(0.9288889, dtype=float32),
#  Array(0.95611113, dtype=float32),
#  Array(0.93, dtype=float32),
#  Array(0.975, dtype=float32),
#  Array(0.9438889, dtype=float32),
#  Array(0.8588889, dtype=float32),
#  Array(0.9666667, dtype=float32),
#  Array(0.92, dtype=float32),
#  Array(0.98222226, dtype=float32),
#  Array(0.9288889, dtype=float32),
#  Array(0.985, dtype=float32),
#  Array(0.94722223, dtype=float32),
#  Array(0.9444445, dtype=float32),
#  Array(0.9727778, dtype=float32),
#  Array(0.995, dtype=float32),
#  Array(0.9161111, dtype=float32),
#  Array(0.96944445, dtype=float32),
#  Array(0.9488889, dtype=float32),
#  Array(0.93833333, dtype=float32),
#  Array(0.9955556, dtype=float32),
#  Array(0.9811111, dtype=float32),
#  Array(0.9294445, dtype=float32),
#  Array(0.9727778, dtype=float32),
#  Array(0.8727778, dtype=float32),
#  Array(0.8794445, dtype=float32),
#  Array(0.79333335, dtype=float32),
#  Array(0.87666667, dtype=float32),
#  Array(0.87666667, dtype=float32),
#  Array(0.93, dtype=float32),
#  Array(0.98611116, dtype=float32),
#  Array(0.9127778, dtype=float32),
#  Array(0.9816667, dtype=float32),
#  Array(0.8238889, dtype=float32),
#  Array(0.9927778, dtype=float32),
#  Array(0.85222226, dtype=float32),
#  Array(0.87, dtype=float32),
#  Array(0.96944445, dtype=float32),
#  Array(0.93333334, dtype=float32),
#  Array(0.9805556, dtype=float32),
#  Array(0.9061111, dtype=float32),
#  Array(0.92, dtype=float32),
#  Array(0.8755556, dtype=float32),
#  Array(0.99333334, dtype=float32),
#  Array(0.98333335, dtype=float32),
#  Array(0.89444447, dtype=float32),
#  Array(0.94555557, dtype=float32),
#  Array(0.8655556, dtype=float32),
#  Array(0.77944446, dtype=float32),
#  Array(0.9166667, dtype=float32),
#  Array(0.9866667, dtype=float32),
#  Array(0.96444446, dtype=float32),
#  Array(0.76500005, dtype=float32),
#  Array(0.91333336, dtype=float32),
#  Array(0.9838889, dtype=float32),
#  Array(0.98611116, dtype=float32),
#  Array(0.9677778, dtype=float32),
#  Array(0.8883334, dtype=float32),
#  Array(0.96944445, dtype=float32),
#  Array(0.93611115, dtype=float32),
#  Array(0.8666667, dtype=float32),
#  Array(0.96333337, dtype=float32),
#  Array(0.9327778, dtype=float32),
#  Array(0.97833335, dtype=float32),
#  Array(0.9855556, dtype=float32),
#  Array(0.9266667, dtype=float32),
#  Array(1., dtype=float32),
#  Array(0.985, dtype=float32),
#  Array(0.9577778, dtype=float32),
#  Array(0.87833333, dtype=float32),
#  Array(0.9816667, dtype=float32),
#  Array(0.9727778, dtype=float32),
#  Array(0.9488889, dtype=float32),
#  Array(0.86611116, dtype=float32),
#  Array(0.9427778, dtype=float32),
#  Array(0.9294445, dtype=float32),
#  Array(0.9888889, dtype=float32),
#  Array(0.9038889, dtype=float32),
#  Array(0.93666667, dtype=float32),
#  Array(0.985, dtype=float32),
#  Array(0.9377778, dtype=float32),
#  Array(0.91, dtype=float32),
#  Array(0.98333335, dtype=float32),
#  Array(0.96500003, dtype=float32),
#  Array(0.9444445, dtype=float32),
#  Array(0.98722225, dtype=float32),
#  Array(0.9522222, dtype=float32),
#  Array(0.96000004, dtype=float32),
#  Array(0.875, dtype=float32),
#  Array(0.9622222, dtype=float32),
#  Array(0.9755556, dtype=float32),
#  Array(0.94166666, dtype=float32),
#  Array(0.91222227, dtype=float32),
#  Array(0.98611116, dtype=float32),
#  Array(0.97444445, dtype=float32),
#  Array(0.9177778, dtype=float32),
#  Array(0.9377778, dtype=float32),
#  Array(0.99222225, dtype=float32),
#  Array(0.95500004, dtype=float32),
#  Array(0.97833335, dtype=float32),
#  Array(0.9905556, dtype=float32),
#  Array(0.95111114, dtype=float32),
#  Array(0.93833333, dtype=float32),
#  Array(0.8655556, dtype=float32),
#  Array(0.9905556, dtype=float32),
#  Array(0.9627778, dtype=float32),
#  Array(0.97944444, dtype=float32),
#  Array(0.9572222, dtype=float32),
#  Array(0.9566667, dtype=float32),
#  Array(0.9427778, dtype=float32),
#  Array(0.89000005, dtype=float32),
#  Array(0.99611115, dtype=float32),
#  Array(0.91944444, dtype=float32),
#  Array(0.97833335, dtype=float32),
#  Array(0.97333336, dtype=float32),
#  Array(0.99833333, dtype=float32),
#  Array(0.97722226, dtype=float32),
#  Array(0.9483334, dtype=float32),
#  Array(0.9427778, dtype=float32),
#  Array(0.9205556, dtype=float32),
#  Array(0.9811111, dtype=float32),
#  Array(0.99722224, dtype=float32),
#  Array(0.99222225, dtype=float32),
#  Array(0.96944445, dtype=float32),
#  Array(0.9666667, dtype=float32),
#  Array(0.9766667, dtype=float32),
#  Array(0.90055555, dtype=float32),
#  Array(0.99333334, dtype=float32),
#  Array(0.985, dtype=float32),
#  Array(0.9483334, dtype=float32),
#  Array(0.97944444, dtype=float32),
#  Array(0.9338889, dtype=float32),
#  Array(0.91, dtype=float32),
#  Array(0.8938889, dtype=float32),
#  Array(0.97944444, dtype=float32),
#  Array(0.90000004, dtype=float32),
#  Array(0.9583334, dtype=float32),
#  Array(0.93722224, dtype=float32),
#  Array(0.9655556, dtype=float32),
#  Array(0.96500003, dtype=float32),
#  Array(0.9338889, dtype=float32),
#  Array(0.9716667, dtype=float32),
#  Array(0.9427778, dtype=float32),
#  Array(0.995, dtype=float32),
#  Array(0.9583334, dtype=float32),
#  Array(0.96944445, dtype=float32),
#  Array(0.9227778, dtype=float32),
#  Array(0.89500004, dtype=float32),
#  Array(0.97944444, dtype=float32),
#  Array(0.9266667, dtype=float32),
#  Array(0.96888894, dtype=float32),
#  Array(0.9588889, dtype=float32),
#  Array(0.9788889, dtype=float32),
#  Array(0.9894445, dtype=float32),
#  Array(0.97, dtype=float32),
#  Array(0.9355556, dtype=float32),
#  Array(0.96833336, dtype=float32),
#  Array(0.9394445, dtype=float32),
#  Array(0.8883334, dtype=float32),
#  Array(0.9655556, dtype=float32),
#  Array(0.91, dtype=float32),
#  Array(0.9488889, dtype=float32),
#  Array(0.9838889, dtype=float32),
#  Array(0.9516667, dtype=float32),
#  Array(0.9705556, dtype=float32),
#  Array(0.9916667, dtype=float32),
#  Array(0.9305556, dtype=float32),
#  Array(0.9816667, dtype=float32),
#  Array(0.9816667, dtype=float32),
#  Array(0.9427778, dtype=float32),
#  Array(0.9116667, dtype=float32),
#  Array(0.99722224, dtype=float32),
#  Array(0.9677778, dtype=float32),
#  Array(0.98444444, dtype=float32),
#  Array(0.9466667, dtype=float32),
#  Array(0.99222225, dtype=float32),
#  Array(0.9622222, dtype=float32),
#  Array(0.9788889, dtype=float32),
#  Array(0.95444447, dtype=float32),
#  Array(0.9166667, dtype=float32),
#  Array(0.94, dtype=float32),
#  Array(0.975, dtype=float32),
#  Array(0.9016667, dtype=float32),
#  Array(0.90055555, dtype=float32),
#  Array(0.97388893, dtype=float32),
#  Array(0.9011111, dtype=float32),
#  Array(0.96000004, dtype=float32),
#  Array(0.9533334, dtype=float32),
#  Array(0.9388889, dtype=float32),
#  Array(0.9672223, dtype=float32),
#  Array(0.9622222, dtype=float32),
#  Array(0.8938889, dtype=float32),
#  Array(0.9105556, dtype=float32),
#  Array(0.9294445, dtype=float32),
#  Array(0.9877778, dtype=float32),
#  Array(0.93111116, dtype=float32),
#  Array(0.98, dtype=float32),
#  Array(0.91722226, dtype=float32),
#  Array(0.91, dtype=float32),
#  Array(0.9672223, dtype=float32),
#  Array(0.9016667, dtype=float32),
#  Array(0.98611116, dtype=float32),
#  Array(0.96888894, dtype=float32),
#  Array(0.8938889, dtype=float32),
#  Array(0.9516667, dtype=float32),
#  Array(0.9533334, dtype=float32),
#  Array(0.97388893, dtype=float32),
#  Array(0.96944445, dtype=float32),
#  Array(0.96833336, dtype=float32),
#  Array(0.89444447, dtype=float32),
#  Array(0.97833335, dtype=float32),
#  Array(0.99333334, dtype=float32),
#  Array(0.9761111, dtype=float32),
#  Array(0.9855556, dtype=float32),
#  Array(0.89111114, dtype=float32),
#  Array(0.9716667, dtype=float32),
#  Array(0.91944444, dtype=float32),
#  Array(0.9977778, dtype=float32),
#  Array(0.935, dtype=float32),
#  Array(0.93333334, dtype=float32),
#  Array(0.9538889, dtype=float32),
#  Array(0.83444446, dtype=float32),
#  Array(0.92, dtype=float32),
#  Array(0.99222225, dtype=float32),
#  Array(0.8966667, dtype=float32),
#  Array(0.9888889, dtype=float32),
#  Array(0.97388893, dtype=float32),
#  Array(0.8938889, dtype=float32),
#  Array(0.99722224, dtype=float32),
#  Array(0.9805556, dtype=float32),
#  Array(0.9816667, dtype=float32),
#  Array(0.9672223, dtype=float32),
#  Array(0.97833335, dtype=float32),
#  Array(0.89111114, dtype=float32),
#  Array(0.9327778, dtype=float32),
#  Array(0.9816667, dtype=float32),
#  Array(0.97222227, dtype=float32),
#  Array(0.8644445, dtype=float32),
#  Array(0.975, dtype=float32),
#  Array(0.90055555, dtype=float32),
#  Array(0.9788889, dtype=float32),
#  Array(0.9988889, dtype=float32),
#  Array(0.9988889, dtype=float32),
#  Array(0.9761111, dtype=float32),
#  Array(0.96500003, dtype=float32),
#  Array(0.88555557, dtype=float32),
#  Array(0.94111115, dtype=float32),
#  Array(0.94, dtype=float32),
#  Array(0.9022222, dtype=float32),
#  Array(0.9866667, dtype=float32),
#  Array(0.94611114, dtype=float32),
#  Array(0.9538889, dtype=float32),
#  Array(0.95055556, dtype=float32),
#  Array(0.97, dtype=float32),
#  Array(0.95444447, dtype=float32),
#  Array(0.9566667, dtype=float32),
#  Array(0.9166667, dtype=float32),
#  Array(0.9627778, dtype=float32),
#  Array(0.90333337, dtype=float32),
#  Array(0.9938889, dtype=float32),
#  Array(0.96888894, dtype=float32),
#  Array(0.99, dtype=float32),
#  Array(0.76, dtype=float32),
#  Array(0.92444444, dtype=float32),
#  Array(0.9616667, dtype=float32),
#  Array(0.9711111, dtype=float32),
#  Array(0.9838889, dtype=float32),
#  Array(0.9655556, dtype=float32),
#  Array(0.9855556, dtype=float32),
#  Array(0.9755556, dtype=float32),
#  Array(0.9811111, dtype=float32),
#  Array(0.98333335, dtype=float32),
#  Array(0.89944446, dtype=float32),
#  Array(0.7427778, dtype=float32),
#  Array(0.9727778, dtype=float32),
#  Array(0.95055556, dtype=float32),
#  Array(0.8066667, dtype=float32),
#  Array(0.9438889, dtype=float32),
#  Array(0.97833335, dtype=float32),
#  Array(0.91444445, dtype=float32),
#  Array(0.9838889, dtype=float32),
#  Array(0.9838889, dtype=float32),
#  Array(0.8666667, dtype=float32),
#  Array(0.87611115, dtype=float32),
#  Array(0.9533334, dtype=float32),
#  Array(0.83500004, dtype=float32),
#  Array(0.99833333, dtype=float32),
#  Array(0.93833333, dtype=float32),
#  Array(0.88722223, dtype=float32),
#  Array(0.94, dtype=float32),
#  Array(0.9855556, dtype=float32),
#  Array(0.9816667, dtype=float32),
#  Array(0.9755556, dtype=float32),
#  Array(0.8983334, dtype=float32),
#  Array(0.88222224, dtype=float32),
#  Array(0.93722224, dtype=float32),
#  Array(0.97944444, dtype=float32),
#  Array(0.9477778, dtype=float32),
#  Array(0.975, dtype=float32),
#  Array(0.9816667, dtype=float32),
#  Array(0.70055556, dtype=float32),
#  Array(0.94611114, dtype=float32),
#  Array(0.90500003, dtype=float32),
#  Array(0.8511111, dtype=float32),
#  Array(0.9527778, dtype=float32),
#  Array(0.90888894, dtype=float32),
#  Array(0.94500005, dtype=float32),
#  Array(0.98333335, dtype=float32),
#  Array(0.9344445, dtype=float32),
#  Array(0.84944445, dtype=float32),
#  Array(0.9655556, dtype=float32),
#  Array(0.8666667, dtype=float32),
#  Array(0.97944444, dtype=float32),
#  Array(0.99666667, dtype=float32),
#  Array(0.93, dtype=float32),
#  Array(0.94166666, dtype=float32),
#  Array(0.94555557, dtype=float32),
#  Array(0.93, dtype=float32),
#  Array(0.9666667, dtype=float32),
#  Array(0.98, dtype=float32),
#  Array(0.96333337, dtype=float32),
#  Array(0.9622222, dtype=float32),
#  Array(0.7672222, dtype=float32),
#  Array(0.9294445, dtype=float32),
#  Array(0.8605556, dtype=float32),
#  Array(0.9927778, dtype=float32)]

# %%
sigma = 0.25 * (1.15 + sd)
noise_sd = sigma[1:]
risk_cor = np.corrcoef([noise_sd, lsc1_risk])[0,1]
width_cor = np.corrcoef([noise_sd, lsc1_width])[0,1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[390], line 3
#       1 sigma = 0.25 * (1.15 + sd)
#       2 noise_sd = sigma[1:]
# ----> 3 risk_cor = np.corrcoef([noise_sd, lsc1_risk])[0,1]
#       4 width_cor = np.corrcoef([noise_sd, lsc1_width])[0,1]
#
# File ~/miniconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2889, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2885 if bias is not np._NoValue or ddof is not np._NoValue:
#    2886     # 2015-03-15, 1.10
#    2887     warnings.warn('bias and ddof have no effect and are deprecated',
#    2888                   DeprecationWarning, stacklevel=2)
# -> 2889 c = cov(x, y, rowvar, dtype=dtype)
#    2890 try:
#    2891     d = diag(c)
#
# File ~/miniconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2659, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2655     raise ValueError(
#    2656         "ddof must be integer")
#    2658 # Handles complex arrays too
# -> 2659 m = np.asarray(m)
#    2660 if m.ndim > 2:
#    2661     raise ValueError("m has more than 2 dimensions")
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
