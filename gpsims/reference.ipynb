# %%
import math
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import jax
import jax.numpy as jnp
import jax.scipy.stats as stats
from jax import jacfwd, jacrev
from jax import vmap, grad, jit, random
from jax.tree_util import tree_map, tree_flatten, tree_unflatten, tree_leaves

from flax import nnx
import optax
import pcax

from tqdm.notebook import tqdm
from tqdm.notebook import trange

# %%
def fourier_sample(rng, n, p, n_freq = 20, intercept = True):
    x = jnp.linspace(0, 1, p)
    f = 0
    for i in range(n_freq):
        rng, key1, key2 = random.split(rng, 3)
        
        an = 1/(i+1) * random.normal(key1, (n, 1))
        bn = 1/(i+1) * random.normal(key2, (n, 1))

        f += an * jnp.cos(2*math.pi * i * x)[None,]
        f += bn * jnp.sin(2*math.pi * i * x)[None,]

    if intercept:
        f += random.normal(rng, (n, 1))
    return f

# %%
def phi_slice(rng, p1, p2):
    phi = random.normal(rng, (p1, p2))
    phi = phi / jnp.sum(phi, axis = 1)[:,None]
    return phi
    
def phi_depth(z, x, w, depth_fn):
    if depth_fn == 'tukey':
        f = jnp.sum(w[:,None] * (z > x), axis = 0)
        depth_1d = 1 - jnp.abs(1 - 2 * f)
    
    elif depth_fn == 'mahal':
        mu = jnp.sum(w[:,None]*x, axis = 0)
        sig = jnp.sqrt(jnp.sum((w[:,None]*x - mu)**2, axis = 0))
        depth_1d = 1/(1+jnp.sqrt((z - mu)**2/sig**2))
        
    elif depth_fn == 'norm':
        norms = jnp.abs(z - x)
        wnorm = jnp.sum(w[:,None] * norms, axis = 0)
        depth_1d = 1/(1+wnorm)

    else: return 0
    return jnp.min(depth_1d)

phi_depth = jit(phi_depth, static_argnames='depth_fn')
vphi_depth = jit(vmap(phi_depth, (0, None, None, None)), static_argnames='depth_fn')

def localizer(xval, xtest, lam, local_fn, self, rng):
    
    if local_fn == 'dexp':
        xtil = xtest[None,] + 1e-2 * jax.random.normal(rng, xtest[None,].shape)
        dist = jnp.max(jnp.abs(xval - xtest), axis = (1, 2))
        dist = dist / jnp.max(dist)
        dist = jnp.exp(-lam * dist)
        local_weights = dist / (jnp.sum(dist) + ind * jnp.exp(-lam * 1e-2))
        
    elif local_fn == 'gaussian':
        xtil = xtest[None,] + 1e-2 * jax.random.normal(rng, xtest[None,].shape)
        dist = jnp.mean((xval - xtest)**2, axis = (1, 2))
        dist = dist / jnp.max(dist)
        dist = jnp.exp(-lam * dist)
        local_weights = dist / (jnp.sum(dist) + ind * jnp.exp(-lam * 1e-2))
        
    elif local_fn == 'knn':
        xtil = xtest[None,] + 1e-2 * jax.random.normal(rng, xtest[None,].shape)
        dist = jnp.max(jnp.abs(xval - xtest), axis = (1, 2))
        dist = dist / jnp.max(dist)
        qdist = jnp.quantile(dist, lam)
        dist = jnp.exp(-dist.at[dist > qdist].set(jnp.inf))
        local_weights = dist / (jnp.sum(dist))
        
    else :
        local_weights = 1/xval.shape[0]
    return local_weights

def lsci_quantile(rval_phi, xval, xtest, alpha, depth_fn, local_fn, lam, rng):

    local_weights = localizer(xval, xtest, lam, local_fn, True, rng)
    dval = vphi_depth(rval_phi, rval_phi, local_weights, depth_fn)

    n = jnp.sum(local_weights > 0)
    adj_alpha = jnp.ceil((n+1)*(1-alpha))/n
    return dval, jnp.quantile(dval, 1-adj_alpha), local_weights

def lsci_sampler(xval, xtest, rval_phi, n_samp, local_fn, lam, rng):
    
    n = rval_phi.shape[0]
    npc = rval_phi.shape[1]
    local_weights = localizer(xval, xtest, lam, local_fn, False, rng)
    
    unif = random.uniform(rng, (n_samp, npc))
    quants = jnp.linspace(jnp.min(rval_phi) - 0.1, jnp.max(rval_phi) + 0.1, n+1)

    samp_cdfs = lsci.lcdf(rval_phi, quants, local_weights / jnp.sum(local_weights))
    samp_quants = jnp.argmax(samp_cdfs[:,:,None] > unif.T[None,:,:], axis = 0)
    samp_phi = quants[samp_quants].T
    return samp_phi

# %%
# scaled metrics
def scaled_linf_dist(x, y):
    d = jnp.max(jnp.abs(x - y))
    return d/(1+d)
scaled_linf_dist = jit(vmap(vmap(scaled_linf_dist, (0, None)), (None, 0)))

def scaled_l2_dist(x, y):
    d = jnp.sqrt(jnp.mean((x - y)**2))
    return d/(1+d)
scaled_l2_dist = jit(vmap(vmap(scaled_l2_dist, (0, None)), (None, 0)))

# localizers
def linf_localizer(xval, xtest, lam):
    dist = scaled_linf_dist(xval, xtest)
    dist = jnp.exp(-lam * dist)
    local_weights = dist / (jnp.exp(-lam) + jnp.sum(dist, axis = 1, keepdims=True))
    return local_weights

def l2_localizer(xval, xtest, lam):
    dist = scaled_l2_dist(xval, xtest)
    dist = jnp.exp(-lam * dist)
    local_weights = dist / (jnp.exp(-lam) + jnp.sum(dist, axis = 1, keepdims=True))
    return local_weights

def knn_localizer(xval, xtest, lam):
    dist = scaled_l2_dist(xval, xtest)
    qdist = jnp.quantile(dist, 1/(1+lam))
    dist = jnp.exp(-dist.at[dist > qdist].set(qdist))
    local_weights = dist / (jnp.exp(-1/lam) + jnp.sum(dist, axis = 1, keepdims=True))
    return local_weights

# phi depths
def weighted_tukey1d(phi_val, phi_test, weights):
    f1 = jnp.sum(weights * (phi_val < phi_test))
    f2 = jnp.sum(weights * (phi_val > phi_test))
    f = jnp.vstack([f1, f2])
    return 2*jnp.min(f)
weighted_tukey1d = vmap(weighted_tukey1d, (None, 0, None))
weighted_tukey1d = vmap(weighted_tukey1d, (1, 1, None))
weighted_tukey1d = jit(weighted_tukey1d)

def weighted_norm1d(phi_val, phi_test, weights):
    f = jnp.sum(weights * jnp.abs(phi_val - phi_test))
    f = jnp.nan_to_num(f)
    return 1/(1 + f)
weighted_norm1d = vmap(weighted_norm1d, (None, 0, None))
weighted_norm1d = vmap(weighted_norm1d, (1, 1, None))
weighted_norm1d = jit(weighted_norm1d)

def weighted_mahal1d(phi_val, phi_test, weights):
    f = jnp.sum(weights * jnp.abs(phi_val - phi_test) / jnp.std(phi_val))
    f = jnp.nan_to_num(f)
    return 1/(1 + f)
weighted_mahal1d = vmap(weighted_mahal1d, (None, 0, None))
weighted_mahal1d = vmap(weighted_mahal1d, (1, 1, None))
weighted_mahal1d = jit(weighted_mahal1d)

def phi_tukey(phi_val, phi_test, weights):
    depth = jnp.min(weighted_tukey1d(phi_val, phi_test, weights), axis = 0)
    return jnp.clip(depth, 0, 1)
phi_tukey = vmap(phi_tukey, (None, None, 0))
phi_tukey = jit(phi_tukey)

def phi_norm(phi_val, phi_test, weights):
    depth = jnp.min(weighted_norm1d(phi_val, phi_test, weights), axis = 0)
    return jnp.clip(depth, 0, 1)
phi_norm = vmap(phi_norm, (None, None, 0))
phi_norm = jit(phi_norm)

def phi_mahal(phi_val, phi_test, weights):
    depth = jnp.min(weighted_mahal1d(phi_val, phi_test, weights), axis = 0)
    return jnp.clip(depth, 0, 1)
phi_mahal = vmap(phi_mahal, (None, None, 0))
phi_mahal = jit(phi_mahal)

## diagonal versions
def vphi_tukey(phi_val, phi_test, weights):
    depth = jnp.min(weighted_tukey1d(phi_val, phi_test, weights), axis = 0)
    return jnp.clip(depth, 0, 1)
vphi_tukey = vmap(vphi_tukey, (None, 0, 0))
vphi_tukey = jit(vphi_tukey)

def vphi_norm(phi_val, phi_test, weights):
    depth = jnp.min(weighted_norm1d(phi_val, phi_test, weights), axis = 0)
    return jnp.clip(depth, 0, 1)
vphi_norm = vmap(vphi_norm, (None, 0, 0))
vphi_norm = jit(vphi_norm)

def vphi_mahal(phi_val, phi_test, weights):
    depth = jnp.min(weighted_mahal1d(phi_val, phi_test, weights), axis = 0)
    return jnp.clip(depth, 0, 1)
vphi_mahal = vmap(vphi_mahal, (None, 0, 0))
vphi_mahal = jit(vphi_mahal)

# %%
### sampler
def local_cdf(x, q, weights):
    f = jnp.sum(weights * (x < q))
    return f
local_cdf = jit(vmap(local_cdf, (None, 0, None)))

def local_quantile(x, cdf, unif):
    return x[jnp.argmax(cdf > unif)]
local_quantile = jit(vmap(local_quantile, (None, None, 0)))

def local_sampler(x, weights, n_samp, rng):
    quants = jnp.linspace(jnp.min(x) - 0.1, jnp.max(x) + 0.1, x.shape[0]+1)
    unif = random.uniform(rng, n_samp)
    lcdf = local_cdf(x, quants, w.T)
    return local_quantile(x, lcdf, unif)
local_sampler = vmap(local_sampler, in_axes = (1, None, None, 0), out_axes = 1)
local_sampler = vmap(local_sampler, (None, 0, None, 1), out_axes = 0)

def pcax_recover(state, ens):
    return pcax.recover(state, ens)
pcax_recover = vmap(pcax_recover, (None, 0))

def phi_project(ens, phi):
    return ens @ phi
vphi_project = vmap(phi_project, (0, None))

def phi_band(ens, depths, thresh):
    sub_ens = ens
    sub_ens = sub_ens.at[depths >= thresh].set(jnp.nan)
    lower = jnp.nanmin(sub_ens, axis = 0)
    upper = jnp.nanmax(sub_ens, axis = 0)
    return jnp.stack([lower, upper])

# %%
# rng = random.PRNGKey(0)
# rng, key1, key2 = random.split(rng, 3)
# x1 = fourier_sample(key1, ntrain, p, n_freq, False)
# x2 = fourier_sample(key2, ntest, p, n_freq, False)

# t = jnp.linspace(0, 1, ntrain+ntest)
# mu = 1 + jnp.sin(6 * jnp.pi * t)

# x1 = mu[:ntrain,None] + x1
# x2 = mu[ntrain:,None] + x2

# rng, key1, key2, key3, key4 = random.split(rng, 5)
# y1 = mu[:ntrain,None] + fourier_sample(key1, ntrain, p, n_freq, False)
# y2 = mu[ntrain:,None] + fourier_sample(key2, ntest, p, n_freq, False)

# %%
rng = random.PRNGKey(0)

# %%
# rng, key3, key4 = random.split(rng, 3)

# # unpack
# lam = 1

# local_weights = linf_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
# phi = phi_slice(key4, p, 100)
# p1 = y1 @ phi
# p2 = y2 @ phi

# k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
# d1 = phi_norm(p1, p1, local_weights) - 1/ntrain
# q1 = jnp.quantile(d1, 1-k, axis = 1)
# d2 = jnp.diag(phi_tukey(p1, p2, local_weights))
# np.mean(d2 > q1)

# %%
ntrain, ntest, p, n_freq = 1000, 500, 100, 21   
alpha = 0.1
n_set = 5
n_sim = 100

rng = random.PRNGKey(0)
cover_linf = np.zeros((n_set, n_sim, ntest))
cover_l2 = np.zeros((n_set, n_sim, ntest))
cover_knn = np.zeros((n_set, n_sim, ntest))

lams = [{'lam': 0.50}, 
        {'lam': 1.00}, 
        {'lam': 2.00}, 
        {'lam': 4.00}, 
        {'lam': 8.00}]

for i in trange(n_sim):
    rng, key1, key2 = random.split(rng, 3)
    x1 = fourier_sample(key1, ntrain, p, n_freq, False)
    x2 = fourier_sample(key2, ntest, p, n_freq, False)
    
    t = jnp.linspace(0, 1, ntrain+ntest)
    mu = 1 + jnp.sin(6 * jnp.pi * t)
    
    x1 = mu[:ntrain,None] + x1
    x2 = mu[ntrain:,None] + x2
    
    rng, key1, key2, key3, key4 = random.split(rng, 5)
    y1 = mu[:ntrain,None] + fourier_sample(key1, ntrain, p, n_freq, False)
    y2 = mu[ntrain:,None] + fourier_sample(key2, ntest, p, n_freq, False)

    ## loop over settings
    for s in range(n_set):
        rng, key3, key4 = random.split(rng, 3)
        
        # unpack
        lam = lams[s]['lam']
        
        local_weights = linf_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
        phi = phi_slice(key4, p, 100)
        p1 = y1 @ phi
        p2 = y2 @ phi
    
        k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
        d1 = phi_tukey(p1, p1, local_weights)
        q1 = jnp.quantile(d1, 1-k, axis = 1)
        d2 = jnp.diag(phi_tukey(p1, p2, local_weights))
        cover_linf[s, i] = (d2 > q1)

    ## loop over settings
    for s in range(n_set):
        rng, key3, key4 = random.split(rng, 3)
        
        # unpack
        lam = lams[s]['lam']
        
        local_weights = l2_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
        phi = phi_slice(key4, p, 100)
        p1 = y1 @ phi
        p2 = y2 @ phi
    
        k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
        d1 = phi_tukey(p1, p1, local_weights)
        q1 = jnp.quantile(d1, 1-k, axis = 1)
        d2 = jnp.diag(phi_tukey(p1, p2, local_weights))
        cover_l2[s, i] = (d2 > q1)

    ## loop over settings
    for s in range(n_set):
        rng, key3, key4 = random.split(rng, 3)
        
        # unpack
        lam = lams[s]['lam']
        
        local_weights = knn_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
        phi = phi_slice(key4, p, 100)
        p1 = y1 @ phi
        p2 = y2 @ phi
    
        k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
        d1 = phi_tukey(p1, p1, local_weights)
        q1 = jnp.quantile(d1, 1-k, axis = 1)
        d2 = jnp.diag(phi_tukey(p1, p2, local_weights))
        cover_knn[s, i] = (d2 > q1)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 48
#      46     q1 = jnp.quantile(d1, 1-k, axis = 1)
#      47     d2 = jnp.diag(phi_tukey(p1, p2, local_weights))
# ---> 48     cover_linf[s, i] = (d2 > q1)
#      50 ## loop over settings
#      51 for s in range(n_set):
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/array.py:430, in ArrayImpl.__array__(self, dtype, context, copy)
#     427 def __array__(self, dtype=None, context=None, copy=None):
#     428   # copy argument is supported by np.asarray starting in numpy 2.0
#     429   kwds = {} if copy is None else {'copy': copy}
# --> 430   return np.asarray(self._value, dtype=dtype, **kwds)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/array.py:629, in ArrayImpl._value(self)
#     627 if self._npy_value is None:
#     628   if self.is_fully_replicated:
# --> 629     self._npy_value = self._single_device_array_to_np_array()
#     630     self._npy_value.flags.writeable = False
#     631     return cast(np.ndarray, self._npy_value)
#
# KeyboardInterrupt:

# %%
print(np.round(np.mean(np.mean(cover_linf, axis = 2), axis = 1), 3))
print(np.round(np.mean(np.mean(cover_l2, axis = 2), axis = 1), 3))
print(np.round(np.mean(np.mean(cover_knn, axis = 2), axis = 1), 3))
# Out:
# [0.905 0.905 0.904 0.906 0.905]
# [0.903 0.904 0.903 0.905 0.908]
# [0.904 0.901 0.902 0.897 0.897]

# %%
print(np.round(2 * np.std(np.mean(cover_linf, axis = 2), axis = 1), 2))
print(np.round(2 * np.std(np.mean(cover_l2, axis = 2), axis = 1), 2))
print(np.round(2 * np.std(np.mean(cover_knn, axis = 2), axis = 1), 2))
# Out:
# [0.03 0.03 0.03 0.03 0.03]
# [0.03 0.03 0.03 0.03 0.03]
# [0.03 0.03 0.03 0.03 0.04]

# %%
plt.boxplot(np.mean(cover_linf, axis = 2).T)
plt.boxplot(np.mean(cover_l2, axis = 2).T)
plt.boxplot(np.mean(cover_knn, axis = 2).T)
plt.show()

# %%
plt.plot(np.mean(cover_linf, axis = 1).T)
plt.plot(np.mean(cover_l2, axis = 1).T)
plt.plot(np.mean(cover_knn, axis = 1).T)
plt.axhline(0.9, c = 'black')
plt.ylim(0.5, 1)
plt.show()
np.mean(cover)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 7
#       5 plt.ylim(0.5, 1)
#       6 plt.show()
# ----> 7 np.mean(cover)
#
# NameError: name 'cover' is not defined

# %%
plt.plot(np.mean(cover_linf, axis = 1).T)
plt.plot(np.mean(cover_l2, axis = 1).T)
plt.plot(np.mean(cover_knn, axis = 1).T)
plt.axhline(0.9, c = 'black')
plt.ylim(0.5, 1)
plt.show()
np.mean(cover)
# Out:
# np.float64(0.902996)

# %%
ntrain, ntest, p, n_freq = 1000, 500, 100, 21   
alpha = 0.1
n_set = 5
n_sim = 100

rng = random.PRNGKey(0)
cover_linf = np.zeros((n_set, n_sim, ntest))
cover_l2 = np.zeros((n_set, n_sim, ntest))
cover_knn = np.zeros((n_set, n_sim, ntest))

lams = [{'lam': 0.50}, 
        {'lam': 1.00}, 
        {'lam': 2.00}, 
        {'lam': 4.00}, 
        {'lam': 8.00}]

for i in trange(n_sim):
    rng, key1, key2 = random.split(rng, 3)
    x1 = fourier_sample(key1, ntrain, p, n_freq, False)
    x2 = fourier_sample(key2, ntest, p, n_freq, False)
    
    t = jnp.linspace(0, 1, ntrain+ntest)
    mu = 1 + jnp.sin(6 * jnp.pi * t)
    
    x1 = mu[:ntrain,None] + x1
    x2 = mu[ntrain:,None] + x2
    
    rng, key1, key2, key3, key4 = random.split(rng, 5)
    y1 = mu[:ntrain,None] + fourier_sample(key1, ntrain, p, n_freq, False)
    y2 = mu[ntrain:,None] + fourier_sample(key2, ntest, p, n_freq, False)

    ## loop over settings
    for s in range(n_set):
        rng, key3, key4 = random.split(rng, 3)
        
        # unpack
        lam = lams[s]['lam']
        
        local_weights = linf_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
        phi = phi_slice(key4, p, 100)
        p1 = y1 @ phi
        p2 = y2 @ phi
    
        k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
        d1 = phi_norm(p1, p1, local_weights)
        q1 = jnp.quantile(d1, 1-k, axis = 1)
        d2 = jnp.diag(phi_norm(p1, p2, local_weights))
        cover_linf[s, i] = (d2 > q1)

    ## loop over settings
    for s in range(n_set):
        rng, key3, key4 = random.split(rng, 3)
        
        # unpack
        lam = lams[s]['lam']
        
        local_weights = l2_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
        phi = phi_slice(key4, p, 100)
        p1 = y1 @ phi
        p2 = y2 @ phi
    
        k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
        d1 = phi_norm(p1, p1, local_weights)
        q1 = jnp.quantile(d1, 1-k, axis = 1)
        d2 = jnp.diag(phi_norm(p1, p2, local_weights))
        cover_l2[s, i] = (d2 > q1)

    ## loop over settings
    for s in range(n_set):
        rng, key3, key4 = random.split(rng, 3)
        
        # unpack
        lam = lams[s]['lam']
        
        local_weights = knn_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
        phi = phi_slice(key4, p, 100)
        p1 = y1 @ phi
        p2 = y2 @ phi
    
        k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
        d1 = phi_norm(p1, p1, local_weights)
        q1 = jnp.quantile(d1, 1-k, axis = 1)
        d2 = jnp.diag(phi_norm(p1, p2, local_weights))
        cover_knn[s, i] = (d2 > q1)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
plt.boxplot(np.mean(cover_linf, axis = 2).T)
plt.boxplot(np.mean(cover_l2, axis = 2).T)
plt.boxplot(np.mean(cover_knn, axis = 2).T)
plt.show()
np.mean(cover_linf), np.mean(cover_l2), np.mean(cover_knn)
# Out:
# (np.float64(0.904436), np.float64(0.906436), np.float64(0.90102))

# %%
plt.plot(np.mean(cover_linf, axis = 1).T)
plt.plot(np.mean(cover_l2, axis = 1).T)
plt.plot(np.mean(cover_knn, axis = 1).T)
plt.axhline(0.9, c = 'black')
plt.ylim(0.5, 1)
plt.show()

# %%
print(np.round(np.mean(np.mean(cover_linf, axis = 2), axis = 1), 3))
print(np.round(np.mean(np.mean(cover_l2, axis = 2), axis = 1), 3))
print(np.round(np.mean(np.mean(cover_knn, axis = 2), axis = 1), 3))
# Out:
# [0.904 0.9   0.903 0.905 0.91 ]
# [0.903 0.905 0.903 0.907 0.914]
# [0.903 0.901 0.902 0.9   0.899]

# %%
print(np.round(2 * np.std(np.mean(cover_linf, axis = 2), axis = 1), 2))
print(np.round(2 * np.std(np.mean(cover_l2, axis = 2), axis = 1), 2))
print(np.round(2 * np.std(np.mean(cover_knn, axis = 2), axis = 1), 2))
# Out:
# [0.03 0.03 0.03 0.03 0.03]
# [0.03 0.03 0.03 0.03 0.03]
# [0.03 0.04 0.03 0.03 0.03]

# %%
ntrain, ntest, p, n_freq = 1000, 500, 100, 21   
alpha = 0.1
n_set = 5
n_sim = 100

rng = random.PRNGKey(0)
cover_linf = np.zeros((n_set, n_sim, ntest))
cover_l2 = np.zeros((n_set, n_sim, ntest))
cover_knn = np.zeros((n_set, n_sim, ntest))

lams = [{'lam': 0.50}, 
        {'lam': 1.00}, 
        {'lam': 2.00}, 
        {'lam': 4.00}, 
        {'lam': 8.00}]

for i in trange(n_sim):
    rng, key1, key2 = random.split(rng, 3)
    x1 = fourier_sample(key1, ntrain, p, n_freq, False)
    x2 = fourier_sample(key2, ntest, p, n_freq, False)
    
    t = jnp.linspace(0, 1, ntrain+ntest)
    mu = 1 + jnp.sin(6 * jnp.pi * t)
    
    x1 = mu[:ntrain,None] + x1
    x2 = mu[ntrain:,None] + x2
    
    rng, key1, key2, key3, key4 = random.split(rng, 5)
    y1 = mu[:ntrain,None] + fourier_sample(key1, ntrain, p, n_freq, False)
    y2 = mu[ntrain:,None] + fourier_sample(key2, ntest, p, n_freq, False)

    ## loop over settings
    for s in range(n_set):
        rng, key3, key4 = random.split(rng, 3)
        
        # unpack
        lam = lams[s]['lam']
        
        local_weights = linf_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
        phi = phi_mahal(key4, p, 100)
        p1 = y1 @ phi
        p2 = y2 @ phi
    
        k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
        d1 = phi_mahal(p1, p1, local_weights)
        q1 = jnp.quantile(d1, 1-k, axis = 1)
        d2 = jnp.diag(phi_norm(p1, p2, local_weights))
        cover_linf[s, i] = (d2 > q1)

    ## loop over settings
    for s in range(n_set):
        rng, key3, key4 = random.split(rng, 3)
        
        # unpack
        lam = lams[s]['lam']
        
        local_weights = l2_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
        phi = phi_slice(key4, p, 100)
        p1 = y1 @ phi
        p2 = y2 @ phi
    
        k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
        d1 = phi_mahal(p1, p1, local_weights)
        q1 = jnp.quantile(d1, 1-k, axis = 1)
        d2 = jnp.diag(phi_mahal(p1, p2, local_weights))
        cover_l2[s, i] = (d2 > q1)

    ## loop over settings
    for s in range(n_set):
        rng, key3, key4 = random.split(rng, 3)
        
        # unpack
        lam = lams[s]['lam']
        
        local_weights = knn_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
        phi = phi_slice(key4, p, 100)
        p1 = y1 @ phi
        p2 = y2 @ phi
    
        k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
        d1 = phi_mahal(p1, p1, local_weights)
        q1 = jnp.quantile(d1, 1-k, axis = 1)
        d2 = jnp.diag(phi_mahal(p1, p2, local_weights))
        cover_knn[s, i] = (d2 > q1)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/climate/lib/python3.12/site-packages/jax/_src/api.py:1021, in _mapped_axis_size.<locals>._get_axis_size(name, shape, axis)
#    1020 try:
# -> 1021   return shape[axis]
#    1022 except (IndexError, TypeError) as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 40
#      37 lam = lams[s]['lam']
#      39 local_weights = linf_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
# ---> 40 phi = phi_mahal(key4, p, 100)
#      41 p1 = y1 @ phi
#      42 p2 = y2 @ phi
#
#     [... skipping hidden 18 frame]
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/api.py:1025, in _mapped_axis_size.<locals>._get_axis_size(name, shape, axis)
#    1023 min_rank = axis + 1 if axis >= 0 else -axis
#    1024 # TODO(mattjj): better error message here
# -> 1025 raise ValueError(
#    1026     f"{name} was requested to map its argument along axis {axis}, "
#    1027     f"which implies that its rank should be at least {min_rank}, "
#    1028     f"but is only {len(shape)} (its shape is {shape})") from e
#
# ValueError: vmap was requested to map its argument along axis 0, which implies that its rank should be at least 1, but is only 0 (its shape is ())

# %%
weight = local_weights(xval2, xtest2, gamma).squeeze()
unif = random.uniform(rng, (nsamp, npc))
quants = jnp.linspace(jnp.min(rval2) - 0.1, jnp.max(rval2) + 0.1, nval+1)

local_cdfs = lcdf(rval2, quants, weight)
local_quants = jnp.argmax(local_cdfs[:,:,None] > unif.T[None,:,:], axis = 0)
local_phi = quants[local_quants].T

# %%
rng, key1, key2 = random.split(rng, 3)
x1 = fourier_sample(key1, ntrain, p, n_freq, False)
x2 = fourier_sample(key2, ntest, p, n_freq, False)

t = jnp.linspace(0, 1, ntrain+ntest)
mu = 1 + jnp.sin(6 * jnp.pi * t)

x1 = mu[:ntrain,None] + x1
x2 = mu[ntrain:,None] + x2

rng, key1, key2, key3, key4 = random.split(rng, 5)
r1 = mu[:ntrain,None] + fourier_sample(key1, ntrain, p, n_freq, False)
r2 = mu[ntrain:,None] + fourier_sample(key2, ntest, p, n_freq, False)

# %%
import pcax
n_proj = 40
n_samp = 2000

# %%
lweights = l2_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), 5).T

state = pcax.fit(y1, n_components = n_proj)
r1_phi = pcax.transform(state, r1)
r2_phi = pcax.transform(state, r2)

rng = random.PRNGKey(0)
rns = random.split(rng, (n_proj, lweights.shape[1]))
ens = local_sample(r1_phi, lweights, n_samp, rns)
ens.shape
# ens = pcax_recover(state, ens)

# k = jnp.ceil((n+1)*(1-alpha))/n
# depth_cal = phi_tukey(r1, r1, lweights.T)
# quant_cal = jnp.quantile(depth_cal, 1-k, axis = 1)
# depth_ens = phi_tukey_diag(r1, ens, lweights)

# lsci_bands = jnp.array([phi_band(ens[i], depth_ens[i], quant_cal[i]) for i in trange(ntest)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 9
#       7 rng = random.PRNGKey(0)
#       8 rns = random.split(rng, (n_proj, lweights.shape[1]))
# ----> 9 ens = local_sample(r1_phi, lweights, n_samp, rns)
#      10 ens.shape
#      11 # ens = pcax_recover(state, ens)
#      12
#      13 # k = jnp.ceil((n+1)*(1-alpha))/n
#    (...)
#      17
#      18 # lsci_bands = jnp.array([phi_band(ens[i], depth_ens[i], quant_cal[i]) for i in trange(ntest)])
#
# NameError: name 'local_sample' is not defined

# %%
### sampler
def local_cdf(x, q, weights):
    f = jnp.sum(weights * (x < q))
    return f
local_cdf = jit(vmap(local_cdf, (None, 0, None)))

def local_quantile(x, cdf, unif):
    return x[jnp.argmax(cdf > unif)]
local_quantile = jit(vmap(local_quantile, (None, None, 0)))

def local_sampler(x, weights, n_samp, rng):
    quants = jnp.linspace(jnp.min(x) - 0.1, jnp.max(x) + 0.1, x.shape[0]+1)
    unif = random.uniform(rng, n_samp)
    lcdf = local_cdf(x, quants, weights.T)
    return local_quantile(x, lcdf, unif)
local_sampler = vmap(local_sampler, in_axes = (1, None, None, 0), out_axes = 1)
local_sampler = vmap(local_sampler, (None, 0, None, 1), out_axes = 0)

def pcax_recover(state, ens):
    return pcax.recover(state, ens)
pcax_recover = vmap(pcax_recover, (None, 0))

def phi_project(ens, phi):
    return ens @ phi
vphi_project = vmap(phi_project, (0, None))

def phi_band(ens, depths, thresh):
    sub_ens = ens
    sub_ens = sub_ens.at[depths >= thresh].set(jnp.nan)
    lower = jnp.nanmin(sub_ens, axis = 0)
    upper = jnp.nanmax(sub_ens, axis = 0)
    return jnp.stack([lower, upper])

# %%
import pcax
n_proj = 40
n_samp = 2000

# %%
lweights = l2_localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), 5)

state = pcax.fit(y1, n_components = n_proj)
r1_phi = pcax.transform(state, r1)
r2_phi = pcax.transform(state, r2)

rng = random.PRNGKey(0)
rns = random.split(rng, (n_proj, ntest))
ens = local_sampler(r1_phi, lweights, n_samp, rns)
ens = pcax_recover(state, ens)

phi = phi_slice(key4, p, 50)
r1_phi = phi_project(r1 ,phi)
ens_phi = vphi_project(ens, phi)

depth_cal = phi_tukey(r1_phi, r1_phi, lweights)
quant_cal = jnp.quantile(depth_cal, 1-k, axis = 1)
depth_ens = vphi_tukey(r1_phi, ens_phi, lweights)

lsci_bands = jnp.array([phi_band(ens[i], depth_ens[i], quant_cal[i]) for i in trange(ntest)])
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 20
#      17 quant_cal = jnp.quantile(depth_cal, 1-k, axis = 1)
#      18 depth_ens = vphi_tukey(r1_phi, ens_phi, lweights)
# ---> 20 lsci_bands = jnp.array([phi_band(ens[i], depth_ens[i], quant_cal[i]) for i in trange(ntest)])
#
# Cell In[18], line 29, in phi_band(ens, depths, thresh)
#      27 def phi_band(ens, depths, thresh):
#      28     sub_ens = ens
# ---> 29     sub_ens = sub_ens.at[depths >= thresh].set(jnp.nan)
#      30     lower = jnp.nanmin(sub_ens, axis = 0)
#      31     upper = jnp.nanmax(sub_ens, axis = 0)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:788, in _IndexUpdateRef.set(self, values, indices_are_sorted, unique_indices, mode)
#     779 def set(self, values, *, indices_are_sorted=False, unique_indices=False,
#     780         mode=None):
#     781   """Pure equivalent of ``x[idx] = y``.
#     782
#     783   Returns the value of ``x`` that would result from the NumPy-style
#    (...)
#     786   See :mod:`jax.ops` for details.
#     787   """
# --> 788   return scatter._scatter_update(self.array, self.index, values, lax.scatter,
#     789                                  indices_are_sorted=indices_are_sorted,
#     790                                  unique_indices=unique_indices, mode=mode)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/ops/scatter.py:76, in _scatter_update(x, idx, y, scatter_op, indices_are_sorted, unique_indices, mode, normalize_indices)
#      73 # XLA gathers and scatters are very similar in structure; the scatter logic
#      74 # is more or less a transpose of the gather equivalent.
#      75 treedef, static_idx, dynamic_idx = jnp._split_index_for_jit(idx, x.shape)
# ---> 76 return _scatter_impl(x, y, scatter_op, treedef, static_idx, dynamic_idx,
#      77                      indices_are_sorted, unique_indices, mode,
#      78                      normalize_indices)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/ops/scatter.py:129, in _scatter_impl(x, y, scatter_op, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, normalize_indices)
#     120 # Transpose the gather dimensions into scatter dimensions (cf.
#     121 # lax._gather_transpose_rule)
#     122 dnums = lax.ScatterDimensionNumbers(
#     123   update_window_dims=indexer.dnums.offset_dims,
#     124   inserted_window_dims=indexer.dnums.collapsed_slice_dims,
#    (...)
#     127   scatter_indices_batching_dims=indexer.dnums.start_indices_batching_dims,
#     128 )
# --> 129 out = scatter_op(
#     130   x, indexer.gather_indices, y, dnums,
#     131   indices_are_sorted=indexer.indices_are_sorted or indices_are_sorted,
#     132   unique_indices=indexer.unique_indices or unique_indices,
#     133   mode=mode)
#     134 if indexer.scalar_bool_dims:
#     135   out = lax.squeeze(out, indexer.scalar_bool_dims)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/lax/slicing.py:836, in scatter(operand, scatter_indices, updates, dimension_numbers, indices_are_sorted, unique_indices, mode)
#     762 def scatter(
#     763   operand: ArrayLike, scatter_indices: ArrayLike, updates: ArrayLike,
#     764   dimension_numbers: ScatterDimensionNumbers, *,
#     765   indices_are_sorted: bool = False, unique_indices: bool = False,
#     766   mode: str | GatherScatterMode | None = None) -> Array:
#     767   """Scatter-update operator.
#     768
#     769   Wraps `XLA's Scatter operator
#    (...)
#     834     Array([0., 2., 3., 0., 4.], dtype=float32)
#     835   """
# --> 836   return scatter_p.bind(
#     837       operand, scatter_indices, updates, update_jaxpr=None,
#     838       update_consts=(), dimension_numbers=dimension_numbers,
#     839       indices_are_sorted=indices_are_sorted, unique_indices=unique_indices,
#     840       mode=GatherScatterMode.from_any(mode))
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/core.py:463, in Primitive.bind(self, *args, **params)
#     461 trace_ctx.set_trace(eval_trace)
#     462 try:
# --> 463   return self.bind_with_trace(prev_trace, args, params)
#     464 finally:
#     465   trace_ctx.set_trace(prev_trace)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/core.py:468, in Primitive.bind_with_trace(self, trace, args, params)
#     467 def bind_with_trace(self, trace, args, params):
# --> 468   return trace.process_primitive(self, args, params)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/core.py:941, in EvalTrace.process_primitive(self, primitive, args, params)
#     939       return primitive.bind_with_trace(arg._trace, args, params)
#     940 check_eval_args(args)
# --> 941 return primitive.impl(*args, **params)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/dispatch.py:90, in apply_primitive(prim, *args, **params)
#      88 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      89 try:
# ---> 90   outs = fun(*args)
#      91 finally:
#      92   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 1 frame]
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/pjit.py:337, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     332 if config.no_tracing.value:
#     333   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     334                      "`jit`, but 'no_tracing' is set")
#     336 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 337  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     339 maybe_fastpath_data = _get_fastpath_data(
#     340     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     341     jaxpr.consts, jit_info.abstracted_axes,
#     342     pgle_profiler)
#     344 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/pjit.py:195, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     193   args_flat = map(core.full_lower, args_flat)
#     194   core.check_eval_args(args_flat)
# --> 195   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     196 else:
#     197   out_flat = pjit_p.bind(*args_flat, **p.params)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/pjit.py:1672, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, compiler_options_kvs, *args)
#    1660 compiler_options_kvs = compiler_options_kvs + tuple(pgle_compile_options.items())
#    1661 # Passing mutable PGLE profile here since it should be extracted by JAXPR to
#    1662 # initialize the fdo_profile compile option.
#    1663 compiled = _resolve_and_lower(
#    1664     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1665     out_shardings=out_shardings, in_layouts=in_layouts,
#    1666     out_layouts=out_layouts, resource_env=resource_env,
#    1667     donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1668     inline=inline, lowering_platforms=None,
#    1669     lowering_parameters=mlir.LoweringParameters(),
#    1670     pgle_profiler=pgle_profiler,
#    1671     compiler_options_kvs=compiler_options_kvs,
# -> 1672 ).compile()
#    1674 # This check is expensive so only do it if enable_checks is on.
#    1675 if compiled._auto_spmd_lowering and config.enable_checks.value:
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2415, in MeshComputation.compile(self, compiler_options)
#    2413 compiler_options_kvs = self._compiler_options_kvs + t_compiler_options
#    2414 if self._executable is None or compiler_options_kvs:
# -> 2415   executable = UnloadedMeshExecutable.from_hlo(
#    2416       self._name, self._hlo, **self.compile_args,
#    2417       compiler_options_kvs=compiler_options_kvs)
#    2418   if not compiler_options_kvs:
#    2419     self._executable = executable
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2923, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2920       break
#    2922 util.test_event("pxla_cached_compilation")
# -> 2923 xla_executable = _cached_compilation(
#    2924     hlo, name, mesh, spmd_lowering,
#    2925     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    2926     allow_prop_to_outputs, tuple(host_callbacks), backend, da, pmap_nreps,
#    2927     compiler_options_kvs, pgle_profiler)
#    2929 if auto_spmd_lowering:
#    2930   assert mesh is not None
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2729, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_kvs, pgle_profiler)
#    2721 compile_options = create_compile_options(
#    2722     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2723     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2724     dev, pmap_nreps, compiler_options)
#    2726 with dispatch.log_elapsed_time(
#    2727     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2728     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2729   xla_executable = compiler.compile_or_get_cached(
#    2730       backend, computation, dev, compile_options, host_callbacks,
#    2731       pgle_profiler)
#    2732 return xla_executable
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/compiler.py:452, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, pgle_profiler)
#     450 else:
#     451   log_persistent_cache_miss(module_name, cache_key)
# --> 452   return _compile_and_write_cache(
#     453       backend,
#     454       computation,
#     455       compile_options,
#     456       host_callbacks,
#     457       module_name,
#     458       cache_key,
#     459   )
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/compiler.py:653, in _compile_and_write_cache(backend, computation, compile_options, host_callbacks, module_name, cache_key)
#     644 def _compile_and_write_cache(
#     645     backend: xc.Client,
#     646     computation: ir.Module,
#    (...)
#     650     cache_key: str,
#     651 ) -> xc.LoadedExecutable:
#     652   start_time = time.monotonic()
# --> 653   executable = backend_compile(
#     654       backend, computation, compile_options, host_callbacks
#     655   )
#     656   compile_time = time.monotonic() - start_time
#     657   _cache_write(
#     658       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     659   )
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/compiler.py:303, in backend_compile(backend, module, options, host_callbacks)
#     297     return backend.compile(
#     298         built_c, compile_options=options, host_callbacks=host_callbacks
#     299     )
#     300   # Some backends don't have `host_callbacks` option yet
#     301   # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     302   # to take in `host_callbacks`
# --> 303   return backend.compile(built_c, compile_options=options)
#     304 except xc.XlaRuntimeError as e:
#     305   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %%
plt.plot(lsci_bands[800,0])
plt.plot(lsci_bands[800,1])

# %%
ens_phi.shape
# Out:
# (500, 2000, 50)

# %%
# weight
local_weights = localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
phi = phi_slice(key4, p, 100)
p1 = y1 @ phi
p2 = y2 @ phi

n2 = jnp.sum(local_weights > 0, axis = 1)
cover1 = []
for i in trange(ntest):
    d1 = jnp.min(weighted_tukey1d(p1, p1, local_weights[i]), axis = 0) - 1/ntrain
    d2 = jnp.min(weighted_tukey1d(p1, p2[i:(i+1)], local_weights[i]), axis = 0)

    # n = n2[i]
    k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
    q1 = jnp.quantile(d1, 1-k)

    cover1.append(d2 >= q1)

np.mean(cover1)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# np.float64(0.894)

# %%
# weight
local_weights = localizer(x1, x2 + 0.1*random.normal(key3, (ntest, p)), lam)
phi = phi_slice(key4, p, 100)
p1 = y1 @ phi
p2 = y2 @ phi

# depths
k = jnp.ceil((ntrain+1)*(1-alpha))/ntrain
d1 = phi_tukey(p1, p1, local_weights) - 1/ntrain
q1 = jnp.quantile(d1, 1-k, axis = 1)
d2 = jnp.diag(phi_tukey(p1, p2, local_weights))
cover2 = (d2 > q1)

# %%
np.mean(cover2)
# Out:
# Array(0.89400005, dtype=float32)

# %%
local_weights = localizer(x1, x2 + 1e-2 * random.normal(rng, x2.shape), lam)
d1 = jnp.min(weighted_tukey1d(p1, p1, local_weights[10]), axis = 0)

# %%
d1
# Out:
# Array([0.14230567, 0.03399634, 0.17145967, 0.26161277, 0.12571567,
#        0.03590727, 0.0803467 , 0.16558146, 0.15877128, 0.5081675 ,
#        0.01783371, 0.18083978, 0.05180335, 0.13100481, 0.08107632,
#        0.01768768, 0.21885121, 0.30350363, 0.17706054, 0.01989716,
#        0.04786021, 0.2797439 , 0.47138023, 0.00992399, 0.222193  ,
#        0.10828811, 0.06029534, 0.06387007, 0.10957879, 0.3727281 ,
#        0.31391865, 0.0282647 , 0.14981705, 0.03789926, 0.04645514,
#        0.02430856, 0.09067154, 0.08503461, 0.07594693, 0.00378072,
#        0.33734202, 0.01581019, 0.36413527, 0.31818974, 0.09050506,
#        0.10828561, 0.08247209, 0.09323537, 0.20443428, 0.01194263,
#        0.13296807, 0.01766503, 0.06824827, 0.13517112, 0.0969969 ,
#        0.36544764, 0.19388342, 0.06202364, 0.06218415, 0.3524074 ,
#        0.23312914, 0.01643097, 0.15795088, 0.37019396, 0.2311266 ,
#        0.06784081, 0.199615  , 0.02595353, 0.13774496, 0.09333217,
#        0.02020961, 0.00975806, 0.1328702 , 0.37059963, 0.14682913,
#        0.70178723, 0.07864136, 0.02596527, 0.4388553 , 0.04593098,
#        0.07434022, 0.        , 0.05184603, 0.39141107, 0.21023095,
#        0.24156666, 0.1640079 , 0.24118316, 0.20657969, 0.01423335,
#        0.12037051, 0.39932346, 0.04600519, 0.33019185, 0.01163447,
#        0.06185007, 0.07825959, 0.01018077, 0.25882202, 0.2270701 ,
#        0.371279  , 0.05106258, 0.60089314, 0.16677105, 0.00393438,
#        0.29084015, 0.19429314, 0.06797886, 0.05426502, 0.11124706,
#        0.00411063, 0.0158534 , 0.01186812, 0.09798479, 0.1689837 ,
#        0.08724856, 0.07360107, 0.09939635, 0.01615471, 0.        ,
#        0.16675544, 0.05315423, 0.14909536, 0.30180162, 0.05169088,
#        0.0845654 , 0.00620413, 0.02835226, 0.01819307, 0.01832783,
#        0.04404521, 0.05472642, 0.27693725, 0.00196654, 0.07202125,
#        0.        , 0.03431171, 0.02800345, 0.04019058, 0.00976992,
#        0.02401423, 0.22743094, 0.02349293, 0.01977432, 0.22352338,
#        0.04587597, 0.35005414, 0.27180767, 0.07589233, 0.001975  ,
#        0.01999938, 0.03175414, 0.01730335, 0.02604711, 0.02369273,
#        0.04344934, 0.05197728, 0.1162222 , 0.08174479, 0.05853355,
#        0.17222202, 0.04836702, 0.32074732, 0.38333285, 0.00201333,
#        0.12318373, 0.06972748, 0.01038957, 0.06208926, 0.10102272,
#        0.38313925, 0.69544816, 0.34877563, 0.07715964, 0.00194067,
#        0.18689626, 0.05595481, 0.24496877, 0.01782537, 0.03636336,
#        0.05823112, 0.3239733 , 0.19754732, 0.1998558 , 0.05390489,
#        0.1041131 , 0.29642648, 0.08489299, 0.20388854, 0.        ,
#        0.07227337, 0.00789267, 0.05672473, 0.03992116, 0.20479012,
#        0.19771898, 0.02623075, 0.05849481, 0.0782252 , 0.30146253,
#        0.14267445, 0.1715424 , 0.16130602, 0.22423446, 0.05783451],      dtype=float32)

# %%
d2 = phi_quantile(p1, x1[:,None,:], x2[:,None,:][k] + 1e-2 * random.normal(rng, x2.shape), 0.1, 'tukey', rng = key)[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_21083/3026130075.py in ?()
# ----> 1 d2 = phi_quantile(p1, x1[:,None,:], x2[:,None,:][k] + 1e-2 * random.normal(rng, x2.shape), 0.1, 'tukey', rng = key)[2]
#
# ~/climate/lib/python3.12/site-packages/jax/_src/array.py in ?(self, idx)
#     367
#     368         return ArrayImpl(
#     369             out.aval, sharding, [out], committed=False, _skip_checks=True)
#     370
# --> 371     return lax_numpy._rewriting_take(self, idx)
#
# ~/climate/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py in ?(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#   11935           isinstance(arr.shape[0], int)):
#   11936         return lax.dynamic_index_in_dim(arr, idx, keepdims=False)
#   11937
#   11938   treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# > 11939   return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#   11940                  unique_indices, mode, fill_value)
#
# ~/climate/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py in ?(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#   11945 def _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#   11946             unique_indices, mode, fill_value):
#   11947   idx = _merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# > 11948   indexer = _index_to_gather(shape(arr), idx)  # shared with _scatter_update
#   11949   y = arr
#   11950
#   11951   if fill_value is not None:
#
# ~/climate/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py in ?(x_shape, idx, normalize_indices)
#   12224       if (abstract_i is not None and
#   12225           not (issubdtype(abstract_i.dtype, integer) or issubdtype(abstract_i.dtype, bool_))):
#   12226         msg = ("Indexer must have integer or boolean type, got indexer "
#   12227                "with type {} at position {}, indexer value {}")
# > 12228         raise TypeError(msg.format(abstract_i.dtype.name, idx_pos, i))
#   12229
#   12230       raise IndexError("Indexing mode not yet supported. Got unsupported indexer "
#   12231                       f"at position {idx_pos}: {i!r}")
#
# TypeError: Indexer must have integer or boolean type, got indexer with type float32 at position 0, indexer value 0.9010000228881836

# %%
plt.scatter(d1, d2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[524], line 1
# ----> 1 plt.scatter(d1, d2)
#
# File ~/climate/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/climate/lib/python3.12/site-packages/matplotlib/pyplot.py:3939, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3919 @_copy_docstring_and_deprecators(Axes.scatter)
#    3920 def scatter(
#    3921     x: float | ArrayLike,
#    (...)
#    3937     **kwargs,
#    3938 ) -> PathCollection:
# -> 3939     __ret = gca().scatter(
#    3940         x,
#    3941         y,
#    3942         s=s,
#    3943         c=c,
#    3944         marker=marker,
#    3945         cmap=cmap,
#    3946         norm=norm,
#    3947         vmin=vmin,
#    3948         vmax=vmax,
#    3949         alpha=alpha,
#    3950         linewidths=linewidths,
#    3951         edgecolors=edgecolors,
#    3952         colorizer=colorizer,
#    3953         plotnonfinite=plotnonfinite,
#    3954         **({"data": data} if data is not None else {}),
#    3955         **kwargs,
#    3956     )
#    3957     sci(__ret)
#    3958     return __ret
#
# File ~/climate/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/climate/lib/python3.12/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/climate/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4900, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4898 y = np.ma.ravel(y)
#    4899 if x.size != y.size:
# -> 4900     raise ValueError("x and y must be the same size")
#    4902 if s is None:
#    4903     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4904          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
# # depths
# n2 = jnp.sum(local_weights > 0, axis = 1)
# k = jnp.ceil((n2+1)*(1-alpha))/n2
# d1 = phi_tukey(p1, p1, local_weights) - 1/ntrain
# q1 = jnp.quantile(d1, 1-k, axis = 1)

# d2 = jnp.diag(phi_tukey(p1, p2, local_weights))
# np.mean(d2 >= q1)

# %%
def phi_quantile(rval_phi, xval, xtest, alpha, depth_fn, rng):
    
    xtil = xtest[None,] + 1e-2 * jax.random.normal(rng, xtest[None,].shape)
    dist = jnp.exp(-jnp.max(jnp.abs(xval - xtil), axis = (1, 2)))
    local_weights = dist / (jnp.sum(dist) + 1)
    
    dval = vphi_depth(rval_phi, rval_phi, local_weights, depth_fn)
    
    n = xval.shape[0]
    adj_alpha = jnp.ceil((n+1)*(1-alpha))/n
    return jnp.quantile(dval, 1-adj_alpha), local_weights, dval
phi_quantile = jit(phi_quantile, static_argnames='depth_fn')

# %%
def phi_quantile(rval_phi, xval, xtest, alpha, depth_fn, rng):
    dist = jnp.exp(-jnp.max(jnp.abs(xval - xtest), axis = (1, 2)))
    dist = dist / (1 + dist)
    local_weights = dist / (jnp.sum(dist) + 1)
    
    dval = vphi_depth(rval_phi, rval_phi, local_weights, depth_fn)
    
    n = xval.shape[0]
    adj_alpha = jnp.ceil((n+1)*(1-alpha))/n
    return jnp.quantile(dval, 1-adj_alpha), local_weights, dval
phi_quantile = jit(phi_quantile, static_argnames='depth_fn')

# %%
##### random basis
phi = phi_slice(rng4, p, 100)
cover = []
for k in trange(ntest):
    rng, key = random.split(rng)
    qval, local_weights, dval = phi_quantile(p1, x1[:,None,:], 
                                             x2[:,None,:][k] + 1e-2 * jax.random.normal(rng, x2.shape),
                                             0.1, 'tukey', rng = key)
    dtest = phi_depth(p2[k], p1, local_weights, 'tukey')
    cover.append(dtest >= qval)

np.mean(cover)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# np.float64(0.898)

# %%
key = random.PRNGKey(0)

# %%
# generate
ntrain, ntest, p = 1000, 200, 100   
alpha = 0.1
lam = 0.1

key, rng1, rng2, rng3 = random.split(key, 4)
x1 = random.normal(rng1, (ntrain, p))
x2 = random.normal(rng2, (ntest, p))

t = jnp.linspace(0, 1, ntrain+ntest)
mu = 1 + jnp.sin(6 * jnp.pi * t)

x1 = mu[:ntrain,None] + x1
x2 = mu[ntrain:,None] + x2

y1 = mu[:ntrain,None]/5 * random.normal(rng1, (ntrain, p))
y2 = mu[ntrain:,None]/5 * random.normal(rng1, (ntest, p))

# weight
local_weights = localizer(x1, x2, lam)

# slice
phi = phi_slice(rng3, p, 200)
p1 = y1 @ phi
p2 = y2 @ phi

# depths
k = jnp.ceil((n+1)*(1-alpha))/n
d1 = phi_tukey(p1, p1, local_weights)
q1 = jnp.quantile(d1, 1-k, axis = 1)

d2 = jnp.diag(phi_tukey(p1, p2, local_weights))
np.mean(d2 >= q1)
# Out:
# Array(0.995, dtype=float32)

# %%
def weighted_tukey1d(pref, ptarget, weights):
    f = jnp.sum(weights * (pref < ptarget))
    f = jnp.nan_to_num(f)
    return 1 - jnp.abs(1 - 2 * f)
weighted_tukey1d = vmap(weighted_tukey1d, (None, 0, None))
weighted_tukey1d = vmap(weighted_tukey1d, (1, 1, None))
# weighted_tukey1d = jit(weighted_tukey1d)

def phi_tukey(pref, ptarget, weights):
    depth = jnp.mean(weighted_tukey1d(pref, ptarget, weights), axis = 0)
    return jnp.clip(depth, 0, 1)
phi_tukey = vmap(phi_tukey, (None, None, 0))

# %%
k = jnp.ceil((n+1)*(1-alpha))/n
d1 = phi_tukey(p1, p1, local_weights)
q1 = jnp.quantile(d1, 1-k, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/climate/lib/python3.12/site-packages/jax/_src/lax/lax.py:174, in _broadcast_shapes_uncached(*shapes)
#     173 try:
# --> 174   return _try_broadcast_shapes(*rank_promoted_shapes, name='broadcast_shapes')
#     175 except TypeError as err:
#     176   # Raise ValueError here for backward compatibility.
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/lax/lax.py:128, in _try_broadcast_shapes(name, *shapes)
#     127     else:
# --> 128       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#     129                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#     130 return tuple(result_shape)
#
# TypeError: broadcast_shapes got incompatible shapes for broadcasting: (1, 100), (100, 20).
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/util.py:302, in cache.<locals>.wrap.<locals>.wrapper(*args, **kwargs)
#     301   return f(*args, **kwargs)
# --> 302 return cached(config.trace_context() if trace_context_in_key else _ignore(),
#     303               *args, **kwargs)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/util.py:296, in cache.<locals>.wrap.<locals>.cached(_, *args, **kwargs)
#     294 @functools.lru_cache(max_size)
#     295 def cached(_, *args, **kwargs):
# --> 296   return f(*args, **kwargs)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/lax/lax.py:158, in _broadcast_shapes_cached(*shapes)
#     156 @cache()
#     157 def _broadcast_shapes_cached(*shapes: tuple[int, ...]) -> tuple[int, ...]:
# --> 158   return _broadcast_shapes_uncached(*shapes)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/lax/lax.py:177, in _broadcast_shapes_uncached(*shapes)
#     175 except TypeError as err:
#     176   # Raise ValueError here for backward compatibility.
# --> 177   raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}") from err
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(100,), (100, 20)]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/lax/lax.py:128, in _try_broadcast_shapes(name, *shapes)
#     127     else:
# --> 128       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#     129                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#     130 return tuple(result_shape)
#
# TypeError: broadcast_shapes got incompatible shapes for broadcasting: (1, 100), (100, 20).
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 2
#       1 k = jnp.ceil((n+1)*(1-alpha))/n
# ----> 2 d1 = phi_tukey(p1, p1, local_weights)
#       3 q1 = jnp.quantile(d1, 1-k, axis = 1)
#
#     [... skipping hidden 6 frame]
#
# Cell In[60], line 19, in phi_tukey(pref, ptarget, weights)
#      18 def phi_tukey(pref, ptarget, weights):
# ---> 19     depth = jnp.mean(weighted_tukey1d(pref, ptarget, weights), axis = 0)
#      20     return jnp.clip(depth, 0, 1)
#
# Cell In[60], line 14, in weighted_tukey1d(pref, ptarget, weights)
#      13 def weighted_tukey1d(pref, ptarget, weights):
# ---> 14     f = jnp.sum(weights * (pref > ptarget))
#      15     f = jnp.nan_to_num(f)
#      16     return 1 - jnp.abs(1 - 2 * f)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:1050, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1049 def op(self, *args):
# -> 1050   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:573, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     571 args = (other, self) if swap else (self, other)
#     572 if isinstance(other, _accepted_binop_types):
# --> 573   return binary_op(*args)
#     574 # Note: don't use isinstance here, because we don't want to raise for
#     575 # subclasses, e.g. NamedTuple objects that may override operators.
#     576 if type(other) in _rejected_binop_types:
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/numpy/ufunc_api.py:179, in ufunc.__call__(self, out, where, *args)
#     177   raise NotImplementedError(f"where argument of {self}")
#     178 call = self.__static_props['call'] or self._call_vectorized
# --> 179 return call(*args)
#
#     [... skipping hidden 13 frame]
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/numpy/ufuncs.py:1255, in multiply(x, y)
#    1228 @binary_ufunc(identity=1, reduce=reductions.prod, accumulate=reductions.cumprod, at=_multiply_at)
#    1229 def multiply(x: ArrayLike, y: ArrayLike, /) -> Array:
#    1230   """Multiply two arrays element-wise.
#    1231
#    1232   JAX implementation of :obj:`numpy.multiply`. This is a universal function,
#    (...)
#    1253     Array([ 0, 10, 20, 30], dtype=int32)
#    1254   """
# -> 1255   x, y = promote_args("multiply", x, y)
#    1256   return lax.mul(x, y) if x.dtype != bool else lax.bitwise_and(x, y)
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/numpy/util.py:194, in promote_args(fun_name, *args)
#     192 _check_no_float0s(fun_name, *args)
#     193 check_for_prngkeys(fun_name, *args)
# --> 194 return promote_shapes(fun_name, *promote_dtypes(*args))
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/numpy/util.py:59, in promote_shapes(fun_name, *args)
#      57 if config.numpy_rank_promotion.value != "allow":
#      58   _rank_promotion_warning_or_error(fun_name, shapes)
# ---> 59 result_rank = len(lax.broadcast_shapes(*shapes))
#      60 return [lax.broadcast_to_rank(arg, result_rank) for arg in args]
#
#     [... skipping hidden 1 frame]
#
# File ~/climate/lib/python3.12/site-packages/jax/_src/lax/lax.py:177, in _broadcast_shapes_uncached(*shapes)
#     174   return _try_broadcast_shapes(*rank_promoted_shapes, name='broadcast_shapes')
#     175 except TypeError as err:
#     176   # Raise ValueError here for backward compatibility.
# --> 177   raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}") from err
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(100,), (100, 20)]

# %%
d2 = jnp.diag(phi_tukey(p1, p2, local_weights))
np.mean(d2 >= q1)
# Out:
# Array(0.97999996, dtype=float32)

# %%
def weighted_tukey1d2(pref, ptarget, weights):
    f = jnp.sum(weights * (pref < ptarget))
    f = jnp.nan_to_num(f)
    return 1 - jnp.abs(1 - 2 * f)
weighted_tukey1d2 = vmap(weighted_tukey1d2, (None, 0, 0))
weighted_tukey1d2 = vmap(weighted_tukey1d2, (1, 1, None))

# %%
d2 = np.mean(weighted_tukey1d2(p1, p2, local_weights), axis = 0)

# %%
np.mean(d2 >= q1)
# Out:
# Array(0.97999996, dtype=float32)

# %%
n_sim = 100
cover = np.zeros(n_sim)

key = 0
n, p = 1000, 200   
alpha = 0.1
lam = 0.1

for i in trange(n_sim):
    # generate
    key += 1
    rng1 = random.PRNGKey(key+1)
    rng2 = random.PRNGKey(key+2)
    x1 = random.normal(rng1, (n, p))
    x2 = random.normal(rng2, (n, p))
    
    t = jnp.linspace(0, 1, n)
    mu = 1 + 3 * t + jnp.sin(2 * jnp.pi * t)
    
    x1 = mu[:,None] + x1
    x2 = mu[:,None] + x2

    y1 = x1 + mu[:,None]/5 * random.normal(rng1, (n, p))
    y2 = x2 + mu[:,None]/5 * random.normal(rng1, (n, p))

    # weight
    local_weights = localizer(x1, x2, lam)

    # slice
    phi = phi_slice(rng, p, 100)
    p1 = y1 @ phi
    p2 = y2 @ phi

    # depths
    d1 = phi_tukey(p1, p1, local_weights)
    d2 = phi_tukey(p1, p2, local_weights)

    # threshold
    idx = int(n - jnp.ceil((n+1)*(1-alpha)))
    q1 = jnp.sort(d1)[idx]

    # cover?
    cover[i] = np.mean(d2 >= q1)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# Out:
# Array(0.29882443, dtype=float32)

# %%
plt.hist(cover)
plt.axvline(np.median(cover), c = 'C1')
plt.show()

# %%
plt.plot(d2)
